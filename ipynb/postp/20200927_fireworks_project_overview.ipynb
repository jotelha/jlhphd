# %% [markdown]
# # Fireworks overview

# %% [markdown]
# This notebook demonstrates querying of Fireworks workflows and Filepad objects

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### IPython magic

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %aimport

# %% [markdown]
# ### Imports

# %%
import ase.io # here used for reading pdb files
from ase.visualize import view
from ase.visualize.plot import plot_atoms # has nasty offset issues
from cycler import cycler # here used for cycling through colors in plots
import datetime
import fabric # for pythonic ssh connections
from fireworks import LaunchPad, Firework, Tracker, Workflow 
from fireworks import FileTransferTask, PyTask, ScriptTask

# FireWorks functionality 
from fireworks import Firework, LaunchPad, ScriptTask, Workflow
from fireworks.user_objects.firetasks.templatewriter_task import TemplateWriterTask
from fireworks.user_objects.firetasks.filepad_tasks import AddFilesTask, GetFilesTask, GetFilesByQueryTask
from imteksimfw.fireworks.user_objects.firetasks.cmd_tasks import CmdTask
from fireworks.utilities.filepad import FilePad # direct FilePad access, similar to the familiar LaunchPad

from collections.abc import Iterable
import glob
import gc # manually clean up memory with gc.collect()
import gromacs # GromacsWrapper, here used for evoking gmc commands, reading and writing .ndx files
# from io import StringIO, TextIOWrapper
import io
from IPython.display import display, Image #, Video # display image files within notebook
from ipywidgets import Video  # display video within notebook
import itertools # for products of iterables
import json # generic serialization of lists and dicts
import jinja2 # here used for filling packmol input script template
import jinja2.meta # for gathering variables in a jinja2 template
import logging 
import matplotlib.pyplot as plt
import MDAnalysis as mda # here used for reading and analyzing gromacs trajectories
import MDAnalysis.analysis.rdf as mda_rdf
import MDAnalysis.analysis.rms as mda_rms
from mpl_toolkits.mplot3d import Axes3D # here used for 3d point cloud scatter plot
import miniball # finds minimum bounding sphere of a point set
import nglview
import numpy as np
import os, os.path
import pandas as pd
import panedr # reads GROMACS edr into pandas df, requires pandas and pbr
import parmed as pmd # has quite a few advantages over ASE when it comes to parsing pdb
from pprint import pprint
import pymongo # for sorting in queries
import scipy.constants as sc
import subprocess # used for evoking external packmol
import sys
import tempfile
import yaml
# Out:
# NOTE: Some configuration directories are not set up yet:
# 	/home/centos/.gromacswrapper
# 	/home/centos/.gromacswrapper/qscripts
# 	/home/centos/.gromacswrapper/templates
# NOTE: You can create the configuration file and directories with:
# 	>>> import gromacs
# 	>>> gromacs.config.setup()

# %% [markdown]
# GromacsWrapper might need a file `~/.gromacswrapper.cfg` with content
# ```cfg
# [Gromacs]
# tools = gmx gmx_d
# # gmx_mpi_d gmx_mpi_d
#
# # name of the logfile that is written to the current directory
# logfilename = gromacs.log
#
# # loglevels (see Python's logging module for details)
# #   ERROR   only fatal errors
# #   WARN    only warnings
# #   INFO    interesting messages
# #   DEBUG   everything
#
# # console messages written to screen
# loglevel_console = INFO
#
# # file messages written to logfilename
# loglevel_file = DEBUG
# ```
# in order to know the GROMACS executables it is allowed to use. Otherwise,
# calls to `gmx_mpi` or `gmx_mpi_d` without MPI wrapper might lead to MPI
# warnings in output that cause GromacsWrapper to fail.

# %% [markdown]
# ### Logging

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ParmEd needs to know the GROMACS topology folder, usually get this from
# envionment variable `GMXLIB`:

# %% [markdown]
# ### Function definitions

# %%
def highlight_bool(s):
    """color boolean values in pandas dataframe"""
    return ['background-color: green' if v else 'background-color: red' for v in s]

# %%
def find_undeclared_variables(infile):
    """identify all variables evaluated in a jinja 2 template file"""
    env = jinja2.Environment()
    with open(infile) as template_file:
        parsed = env.parse(template_file.read())

    undefined = jinja2.meta.find_undeclared_variables(parsed)
    return undefined

# %%
def memuse():
    """Quick overview on memory usage of objects in Jupyter notebook"""
    # https://stackoverflow.com/questions/40993626/list-memory-usage-in-ipython-and-jupyter
    # These are the usual ipython objects, including this one you are creating
    ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

    # Get a sorted list of the objects and their sizes
    return sorted([(x, sys.getsizeof(globals().get(x))) for x in dir(sys.modules['__main__']) if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)

# %% [markdown]
# ### Global settings

# %%
# pandas settings
# https://songhuiming.github.io/pages/2017/04/02/jupyter-and-pandas-display/
pd.options.display.max_rows = 200
pd.options.display.max_columns = 16
pd.options.display.max_colwidth = 256
pd.options.display.max_colwidth = None

# %%
os.environ['GMXLIB'] = '/gmx_top'

# %%
# pmd.gromacs.GROMACS_TOPDIR = os.environ['GMXLIB']
pmd.gromacs.GROMACS_TOPDIR = '/gmx_top'

# %%
# prefix = '/mnt/dat/work/testuser/indenter/sandbox/20191110_packmol'
prefix = '/mnt/dat/work'

# %%
work_prefix = '/mnt/dat/work/tmp'

# %%
try:
    os.mkdir(work_prefix)
except FileExistsError as exc:
    print(exc)
# Out:
# [Errno 17] File exists: '/mnt/dat/work/tmp'

# %%
os.chdir(work_prefix)

# %%
# the FireWorks LaunchPad
lp = LaunchPad.auto_load() #Define the server and database
# FilePad behaves analogous to LaunchPad
fp = FilePad.auto_load()

# %% [markdown]
# # Fireworks

# %%
project = '2020-09-28-ctab-on-au-111-substrate-passivation'

# %%
query={'spec.metadata.project': project}

# %%
fw_ids = lp.get_fw_ids(query)

# %%
len(fw_ids)
# Out:
# 3479

# %%
wf_query = {'nodes': {'$in': fw_ids}}

# %%
lp.workflows.count_documents(wf_query)
# Out:
# 1

# %%
wf = lp.workflows.find_one(wf_query)

# %%
wf.keys()
# Out:
# dict_keys(['_id', 'links', 'parent_links', 'nodes', 'metadata', 'state', 'name', 'created_on', 'updated_on', 'fw_states'])

# %%
fw_ids = wf['nodes']

# %%
fw = lp.fireworks.find_one()

# %%
fw
# Out:
# {'_id': ObjectId('5b76cead2512e1d04c868d05'),
#  'spec': {'_tasks': [{'script': ['./replicate.sh 17 10 2 111'],
#     'use_shell': True,
#     '_fw_name': 'ScriptTask'},
#    {'script': ['./replicate.sh 26 15 2 111'],
#     'use_shell': True,
#     '_fw_name': 'ScriptTask'},
#    {'script': ['./replicate.sh 51 30 2 111'],
#     'use_shell': True,
#     '_fw_name': 'ScriptTask'},
#    {'script': ['./replicate.sh 60 35 2 111'],
#     'use_shell': True,
#     '_fw_name': 'ScriptTask'}]},
#  'fw_id': 2,
#  'created_on': '2018-08-17T13:32:38.908251',
#  'updated_on': '2018-08-17T13:39:44.092056',
#  'launches': [2],
#  'state': 'COMPLETED',
#  'name': 'SDS on AU 111 Substrate Replication',
#  'archived_launches': []}

# %%
query = {'fw_id': {'$in': fw_ids}}

# %%
lp.fireworks.count_documents(query)
# Out:
# 3479

# %%
query = {'fw_id': {'$in': fw_ids}, 'name': {'$regex':'NPT'}}

# %%
lp.fireworks.count_documents(query)
# Out:
# 528

# %%
query = {'fw_id': {'$in': fw_ids}, 'name': {'$regex':'NPT.*mdrun'}, 'state': 'COMPLETED'}

# %%
lp.fireworks.count_documents(query)
# Out:
# 38

# %%
fw = lp.fireworks.find_one(query)

# %%
fw['fw_id']
# Out:
# 50932

# %%
fw['name']
# Out:
# 'n=1944, m=1944, s=bilayer, SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:GromacsNPTEquilibrationMain:gmx_mdrun'

# %%
fw['state']
# Out:
# 'COMPLETED'

# %%
fw['spec']['metadata']['step_specific']
# Out:
# {'conversion': {'lmp_type_to_element_mapping': {'11': 'Au'},
#   'element_to_pdb_atom_name_mapping': {'Au': 'AU'},
#   'element_to_pdb_residue_name_mapping': {'Au': 'AUM'}},
#  'packing': {'surfactant_substrate': {'tolerance': 1.5,
#    'constraints': {'layers': [{'bounding_box': [[-98.572, -99.281, 101.617],
#        [100.226, 100.354, 126.03802096329918]],
#       'lower_constraint_plane': 105.37984599543711,
#       'upper_constraint_plane': 122.27517496786207},
#      {'bounding_box': [[-98.572, -99.281, 126.03802096329918],
#        [100.226, 100.354, 150.45904192659833]],
#       'lower_constraint_plane': 129.80086695873626,
#       'upper_constraint_plane': 146.69619593116124}]}}},
#  'dtool_push': {'dtool_target': '/p/project/chfr13/hoermann4/dtool/DATASETS',
#   'remote_dataset': {'uri': 'file://juwels01.ib.juwels.fzj.de/p/project/chfr13/hoermann4/dtool/DATASETS/2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation',
#    'uuid': 'b01be676-2a01-45ae-94b3-f2eaa96aa388',
#    'name': '2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation'},
#   'local_proto_dataset': {'uri': 'file://juwels01.ib.juwels.fzj.de/p/scratch/chfr13/hoermann/fireworks/launchpad/launcher_2020-09-28-19-38-26-084883/2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation',
#    'uuid': 'b01be676-2a01-45ae-94b3-f2eaa96aa388',
#    'name': '2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation'},
#   'local_frozen_dataset': {'uri': 'file://juwels01.ib.juwels.fzj.de/p/scratch/chfr13/hoermann/fireworks/launchpad/launcher_2020-09-28-19-38-26-084883/2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation',
#    'uuid': 'b01be676-2a01-45ae-94b3-f2eaa96aa388',
#    'name': '2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation'}}}

# %%
fw['spec']['metadata']['step_specific']
# Out:
# {'conversion': {'lmp_type_to_element_mapping': {'11': 'Au'},
#   'element_to_pdb_atom_name_mapping': {'Au': 'AU'},
#   'element_to_pdb_residue_name_mapping': {'Au': 'AUM'}},
#  'packing': {'surfactant_substrate': {'tolerance': 1.5,
#    'constraints': {'layers': [{'bounding_box': [[-98.572, -99.281, 101.617],
#        [100.226, 100.354, 126.03802096329918]],
#       'lower_constraint_plane': 105.37984599543711,
#       'upper_constraint_plane': 122.27517496786207},
#      {'bounding_box': [[-98.572, -99.281, 126.03802096329918],
#        [100.226, 100.354, 150.45904192659833]],
#       'lower_constraint_plane': 129.80086695873626,
#       'upper_constraint_plane': 146.69619593116124}]}}},
#  'dtool_push': {'dtool_target': '/p/project/chfr13/hoermann4/dtool/DATASETS',
#   'remote_dataset': {'uri': 'file://juwels01.ib.juwels.fzj.de/p/project/chfr13/hoermann4/dtool/DATASETS/2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation',
#    'uuid': 'b01be676-2a01-45ae-94b3-f2eaa96aa388',
#    'name': '2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation'},
#   'local_proto_dataset': {'uri': 'file://juwels01.ib.juwels.fzj.de/p/scratch/chfr13/hoermann/fireworks/launchpad/launcher_2020-09-28-19-38-26-084883/2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation',
#    'uuid': 'b01be676-2a01-45ae-94b3-f2eaa96aa388',
#    'name': '2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation'},
#   'local_frozen_dataset': {'uri': 'file://juwels01.ib.juwels.fzj.de/p/scratch/chfr13/hoermann/fireworks/launchpad/launcher_2020-09-28-19-38-26-084883/2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation',
#    'uuid': 'b01be676-2a01-45ae-94b3-f2eaa96aa388',
#    'name': '2020-09-28-02-11-42-503121-n-1944-m-1944-s-bilayer-substratepassivation'}}}

# %% [markdown]
# # Filepad

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Overview on recent projects in database

# %%
query = {'metadata.datetime': {'$gt': '2020'} }

# %%
fp.filepad.count_documents(query)
# Out:
# 11975

# %%
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 'project': '$metadata.project' },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # pull 'project' field up in hierarchy
        "$addFields": { 
            "project": "$_id.project",
        },
    },
    {  # drop nested '_id.project'
        "$project": { 
            "_id": False 
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

# sort_aggregation
#aggregation_pipeline = [ match_aggregation, group_aggregation, set_aggregation ]
cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [c for c in cursor]
res_df = pd.DataFrame(data=res) # pandas Dataframe is just nice for printing in notebook

# %%
res_df
# Out:
#                                                                                                                                                                                                step  \
# 0                                                                 SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsRelaxation:push_filepad
# 1                                                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:push_filepad
# 2                                                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNVTEquilibration:push_filepad
# 3                                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
# 4                                                                    SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 5                                                                       SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 6                                                                                                                   SubstratePassivation:CylindricalPackingAndEquilibartion:PDBCleanup:push_filepad
# 7                                                                                    SubstratePassivation:CylindricalPackingAndEquilibartion:CylindricalPacking:CylindricalPackingMain:push_filepad
# 8                                                                     SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsRelaxation:push_filepad
# 9                                                               SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:push_filepad
# 10                                                              SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNVTEquilibration:push_filepad
# 11                                              SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
# 12                                                                       SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 13                                                                          SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 14                                                                                                                      SubstratePassivation:BilayerPackingAndEquilibartion:PDBCleanup:push_filepad
# 15                                                                                               SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_filepad
# 16                                                                                                                   SubstratePassivation:ComponentMeasures:SurfactantMoleculeMeasures:push_filepad
# 17                                                                                                        SubstratePassivation:ComponentMeasures:SubstratePreparation:FormatConversion:push_filepad
# 18                                                          SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:GromacsPrepMain:push_infiles
# 19               SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:GromacsTrajectoryVisualization:push_infiles
# 20                                                                                               SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_infiles
# 21                                  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:GromacsNPTEquilibrationMain:push_infiles
# 22                                                                                    SubstratePassivation:ComponentMeasures:SurfactantMoleculeMeasures:SurfactantMoleculeMeasuresMain:push_infiles
# 23                                  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNVTEquilibration:GromacsNVTEquilibrationMain:push_infiles
# 24  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:GromacsEnergyMinimizationAfterSolvationMain:push_infiles
# 25                                              SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsRelaxation:GromacsRelaxationMain:push_infiles
#
#                       earliest                      latest  object_count
# 0   2020-10-13 23:31:57.836878  2020-10-13 23:31:58.351891           206
# 1   2020-10-13 23:31:57.830704  2020-10-13 23:31:58.346478           252
# 2   2020-10-13 23:31:57.825805  2020-10-13 23:31:58.642317           273
# 3   2020-10-13 23:31:57.819787  2020-10-13 23:31:58.871696           483
# 4   2020-10-13 23:31:57.815064  2020-10-13 23:31:58.866987            48
# 5   2020-10-13 23:31:57.814932  2020-10-13 23:31:58.866857            48
# 6   2020-10-13 23:31:57.814621  2020-10-13 23:31:58.866480            24
# 7   2020-10-13 23:31:57.814415  2020-10-13 23:31:58.866236            24
# 8   2020-10-13 23:31:57.814026  2020-10-13 23:31:58.865832           176
# 9   2020-10-13 23:31:57.808419  2020-10-13 23:31:58.860104           315
# 10  2020-10-13 23:31:57.803220  2020-10-13 23:31:58.855226           357
# 11  2020-10-13 23:31:57.798467  2020-10-13 23:31:58.850377           462
# 12  2020-10-13 23:31:57.793538  2020-10-13 23:31:58.844403            48
# 13  2020-10-13 23:31:57.793400  2020-10-13 23:31:58.844100            48
# 14  2020-10-13 23:31:57.793073  2020-10-13 23:31:58.843344            24
# 15  2020-10-13 23:31:57.792866  2020-10-13 23:31:58.842868            24
# 16  2020-10-13 23:31:57.792495  2020-10-13 23:31:57.792501             2
# 17  2020-10-13 23:31:57.716886  2020-10-13 23:31:57.716886             1
# 18                        None                        None             1
# 19                        None                        None             1
# 20                        None                        None             2
# 21                        None                        None             1
# 22                        None                        None             1
# 23                        None                        None             1
# 24                        None                        None             1
# 25                        None                        None             1

# %% [markdown]
# ### Overview on recent production projects in database

# %%
query = {
    'metadata.datetime': {'$gt': '2020'},
    'metadata.mode': 'production'
}

# %%
fp.filepad.count_documents(query)
# Out:
# 9563

# %%
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 'project': '$metadata.project' },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # pull 'project' field up in hierarchy
        "$addFields": { 
            "project": "$_id.project",
        },
    },
    {  # drop nested '_id.project'
        "$project": { 
            "_id": False 
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

# sort_aggregation
#aggregation_pipeline = [ match_aggregation, group_aggregation, set_aggregation ]
cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [c for c in cursor]
res_df = pd.DataFrame(data=res) # pandas Dataframe is just nice for printing in notebook

# %%
res_df
# Out:
#    object_count                    earliest                      latest  \
# 0            53  2020-10-24 19:50:57.364604  2020-10-24 19:50:57.367249
# 1            53  2020-10-20 00:36:42.139788  2020-10-20 00:36:42.145747
# 2          2815  2020-10-13 23:31:57.716886  2020-10-13 23:31:58.871696
# 3          2703  2020-09-28 02:11:38.861517  2020-09-28 02:11:42.558642
# 4            53  2020-09-27 18:58:47.134481  2020-09-27 18:58:47.137826
# 5            53  2020-09-26 14:45:31.896748  2020-09-26 14:45:31.898524
# 6            53  2020-09-26 00:33:42.497547  2020-09-26 00:33:42.499737
# 7          2844  2020-09-14 19:40:24.649384  2020-09-14 19:40:26.998397
# 8           537  2020-07-29 03:50:20.375090  2020-07-29 03:50:22.884335
# 9           399  2020-07-29 03:47:40.301419  2020-07-29 03:47:42.358240
#
#                                              project
# 0  2020-10-24-au-111-150x150x150-fcc-substrate-cr...
# 1  2020-10-19-au-111-150x150x150-fcc-substrate-cr...
# 2    2020-10-13-ctab-on-au-111-substrate-passivation
# 3    2020-09-28-ctab-on-au-111-substrate-passivation
# 4           2020-09-27-au-111-fcc-substrate-creation
# 5     2020-09-26-au-111-fcc-substrate-creation-trial
# 6           2020-09-25-au-111-fcc-substrate-creation
# 7     2020-09-14-sds-on-au-111-substrate-passivation
# 8     2020-07-29-ctab-on-au-111-indenter-passivation
# 9      2020-07-29-sds-on-au-111-indenter-passivation

# %% [markdown]
# ### Overview on steps in project

# %%
#project_id = '2020-09-28-ctab-on-au-111-substrate-passivation'
project_id = '2020-10-13-ctab-on-au-111-substrate-passivation'

# %%
# queries to the data base are simple dictionaries
query = {
    'metadata.project': project_id,
}

# %%
# use underlying MongoDB functionality to check total number of documents matching query
fp.filepad.count_documents(query)
# Out:
# 2824

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'step': '$metadata.step',
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['step', 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_df
# Out:
#                                                                                                                                                                                                step  \
# 0                                                                 SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsRelaxation:push_filepad
# 1                                                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:push_filepad
# 2                                                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNVTEquilibration:push_filepad
# 3                                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
# 4                                                                    SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 5                                                                       SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 6                                                                                                                   SubstratePassivation:CylindricalPackingAndEquilibartion:PDBCleanup:push_filepad
# 7                                                                                    SubstratePassivation:CylindricalPackingAndEquilibartion:CylindricalPacking:CylindricalPackingMain:push_filepad
# 8                                                                     SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsRelaxation:push_filepad
# 9                                                               SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:push_filepad
# 10                                                              SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNVTEquilibration:push_filepad
# 11                                              SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
# 12                                                                       SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 13                                                                          SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 14                                                                                                                      SubstratePassivation:BilayerPackingAndEquilibartion:PDBCleanup:push_filepad
# 15                                                                                               SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_filepad
# 16                                                                                                                   SubstratePassivation:ComponentMeasures:SurfactantMoleculeMeasures:push_filepad
# 17                                                                                                        SubstratePassivation:ComponentMeasures:SubstratePreparation:FormatConversion:push_filepad
# 18                                                          SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:GromacsPrepMain:push_infiles
# 19               SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:GromacsTrajectoryVisualization:push_infiles
# 20                                                                                               SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_infiles
# 21                                  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:GromacsNPTEquilibrationMain:push_infiles
# 22                                                                                    SubstratePassivation:ComponentMeasures:SurfactantMoleculeMeasures:SurfactantMoleculeMeasuresMain:push_infiles
# 23                                  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNVTEquilibration:GromacsNVTEquilibrationMain:push_infiles
# 24  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:GromacsEnergyMinimizationAfterSolvationMain:push_infiles
# 25                                              SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsRelaxation:GromacsRelaxationMain:push_infiles
#
#                       earliest                      latest  object_count
# 0   2020-10-13 23:31:57.836878  2020-10-13 23:31:58.351891           206
# 1   2020-10-13 23:31:57.830704  2020-10-13 23:31:58.346478           252
# 2   2020-10-13 23:31:57.825805  2020-10-13 23:31:58.642317           273
# 3   2020-10-13 23:31:57.819787  2020-10-13 23:31:58.871696           483
# 4   2020-10-13 23:31:57.815064  2020-10-13 23:31:58.866987            48
# 5   2020-10-13 23:31:57.814932  2020-10-13 23:31:58.866857            48
# 6   2020-10-13 23:31:57.814621  2020-10-13 23:31:58.866480            24
# 7   2020-10-13 23:31:57.814415  2020-10-13 23:31:58.866236            24
# 8   2020-10-13 23:31:57.814026  2020-10-13 23:31:58.865832           176
# 9   2020-10-13 23:31:57.808419  2020-10-13 23:31:58.860104           315
# 10  2020-10-13 23:31:57.803220  2020-10-13 23:31:58.855226           357
# 11  2020-10-13 23:31:57.798467  2020-10-13 23:31:58.850377           462
# 12  2020-10-13 23:31:57.793538  2020-10-13 23:31:58.844403            48
# 13  2020-10-13 23:31:57.793400  2020-10-13 23:31:58.844100            48
# 14  2020-10-13 23:31:57.793073  2020-10-13 23:31:58.843344            24
# 15  2020-10-13 23:31:57.792866  2020-10-13 23:31:58.842868            24
# 16  2020-10-13 23:31:57.792495  2020-10-13 23:31:57.792501             2
# 17  2020-10-13 23:31:57.716886  2020-10-13 23:31:57.716886             1
# 18                        None                        None             1
# 19                        None                        None             1
# 20                        None                        None             2
# 21                        None                        None             1
# 22                        None                        None             1
# 23                        None                        None             1
# 24                        None                        None             1
# 25                        None                        None             1

# %% [markdown]
# #### Pivot overview on steps and parameters in project

# %%
project_id = '2020-10-13-ctab-on-au-111-substrate-passivation'

# %%
query = {
    'metadata.project': project_id,
    'metadata.system.surfactant.nmolecules': {'$exists': True},
    'metadata.system.surfactant.aggregates.shape': {'$exists': True},
}

# %%
# use underlying MongoDB functionality to check total number of documents matching query
fp.filepad.count_documents(query)
# Out:
# 2816

# %%
parameters = { 
    'nmolecules': 'metadata.system.surfactant.nmolecules',
    'shape': 'metadata.system.surfactant.aggregates.shape',
}

# %%
distinct_parameter_values = {}
for label, key in parameters.items():
    values = fp.filepad.distinct(key, query)
    if None in values:
        values.remove(None)
    distinct_parameter_values[label] = values

# %%
print(distinct_parameter_values)
# Out:
# {'nmolecules': [81, 162, 243, 324, 405, 486, 567, 648, 729, 810, 891, 972, 1053, 1134, 1215, 1296, 1377, 1458, 1539, 1620, 1701, 1782, 1863, 1944], 'shape': ['bilayer', 'cylinders']}

# %% [markdown]
# #### Refined aggregation for hemicylindrical systems

# %%
distinct_parameter_values['shape'].remove('bilayer')

# %%
query = {
    'metadata.project': project_id,
    **{parameters[label]: {'$in': values} for label, values in distinct_parameter_values.items()}
}

# %%
print(query)
# Out:
# {'metadata.project': '2020-10-13-ctab-on-au-111-substrate-passivation', 'metadata.system.surfactant.nmolecules': {'$in': [81, 162, 243, 324, 405, 486, 567, 648, 729, 810, 891, 972, 1053, 1134, 1215, 1296, 1377, 1458, 1539, 1620, 1701, 1782, 1863, 1944]}, 'metadata.system.surfactant.aggregates.shape': {'$in': ['cylinders']}}

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'step': '$metadata.step',
                **{label: '${}'.format(key) for label, key in parameters.items()},
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['step', *parameters.keys(), 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_pivot = res_df.pivot_table(values='object_count', index=['step'], columns=list(parameters.keys()), aggfunc=pd.notna, fill_value=False)
res_pivot.style.apply(highlight_bool)
# Out:
# <style  type="text/css" >
#     #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col0 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col1 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col2 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col3 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col4 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col5 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col6 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col7 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col8 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col9 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col10 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col11 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col12 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col13 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col14 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col15 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col16 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col17 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col18 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col19 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col20 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col21 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col22 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row0_col23 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col0 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col1 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col2 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col3 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col4 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col5 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col6 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col7 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col8 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col9 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col10 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col11 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col12 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col13 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col14 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col15 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col16 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col17 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col18 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col19 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col20 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col21 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col22 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row1_col23 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col0 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col1 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col2 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col3 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col4 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col5 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col6 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col7 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col8 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col9 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col10 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col11 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col12 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col13 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col14 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col15 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col16 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col17 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col18 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col19 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col20 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col21 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col22 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row2_col23 {
#             background-color:  red;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row3_col0 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row3_col1 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row3_col2 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row3_col3 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row3_col4 {
#             background-color:  green;
#         }    #T_622cac8c_1793_11eb_8fce_fa163e14e704row3_col5 {
#             background-color:  green;
#         }

# %% [markdown]
# #### Refined aggregation for bilayer systems

# %%
distinct_parameter_values['shape'].remove('cylinders')
distinct_parameter_values['shape'].append('bilayer')

# %%
query = {
    'metadata.project': project_id,
    **{parameters[label]: {'$in': values} for label, values in distinct_parameter_values.items()}
}

# %%
print(query)
# Out:
# {'metadata.project': '2020-10-13-ctab-on-au-111-substrate-passivation', 'metadata.system.surfactant.nmolecules': {'$in': [81, 162, 243, 324, 405, 486, 567, 648, 729, 810, 891, 972, 1053, 1134, 1215, 1296, 1377, 1458, 1539, 1620, 1701, 1782, 1863, 1944]}, 'metadata.system.surfactant.aggregates.shape': {'$in': ['bilayer']}}

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'step': '$metadata.step',
                **{label: '${}'.format(key) for label, key in parameters.items()},
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['step', *parameters.keys(), 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_pivot = res_df.pivot_table(values='object_count', index=['step'], columns=list(parameters.keys()), aggfunc=pd.notna, fill_value=False)
res_pivot.style.apply(highlight_bool)
# Out:
# <style  type="text/css" >
#     #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col0 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col1 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col2 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col3 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col4 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col5 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col6 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col7 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col8 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col9 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col10 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col11 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col12 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col13 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col14 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col15 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col16 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col17 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col18 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col19 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col20 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col21 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col22 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row0_col23 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col0 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col1 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col2 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col3 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col4 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col5 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col6 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col7 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col8 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col9 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col10 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col11 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col12 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col13 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col14 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col15 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col16 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col17 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col18 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col19 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col20 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col21 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col22 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row1_col23 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col0 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col1 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col2 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col3 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col4 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col5 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col6 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col7 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col8 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col9 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col10 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col11 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col12 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col13 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col14 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col15 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col16 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col17 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col18 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col19 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col20 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col21 {
#             background-color:  red;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col22 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row2_col23 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row3_col0 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row3_col1 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row3_col2 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row3_col3 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row3_col4 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_8fce_fa163e14e704row3_col5 {
#             background-color:  green;
#         }    #T_3241c482_1796_11eb_

# %%
res_df.groupby(['step', *parameters.keys()])

# %%
res_df.set_index('step').stack()
# Out:
# step
# SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad  nmolecules                            1944
#                                                                                                                                                          shape                            cylinders
#                                                                                                                                                          earliest        2020-10-13 23:31:58.871647
#                                                                                                                                                          latest          2020-10-13 23:31:58.871696
#                                                                                                                                                          object_count                            21
#                                                                                                                                                                                     ...
# SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_filepad                                                       latest          2020-10-13 23:31:57.792866
#                                                                                                                                                          object_count                             1
# SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_infiles                                                       nmolecules                              81
#                                                                                                                                                          shape                              bilayer
#                                                                                                                                                          object_count                             1
# Length: 1593, dtype: object

# %%
(res_df.set_index('step').stack()
 .groupby(level=[0,1])
 .value_counts()
 .unstack(level=[1,2])
 .fillna(0)
 .sort_index(axis=1))

# %%
res_df.groupby()
# Out:
#                                                                                                                                                         step  \
# 0    SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
# 1                             SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 2                                SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 3                                                                            SubstratePassivation:CylindricalPackingAndEquilibartion:PDBCleanup:push_filepad
# 4                                             SubstratePassivation:CylindricalPackingAndEquilibartion:CylindricalPacking:CylindricalPackingMain:push_filepad
# ..                                                                                                                                                       ...
# 314                               SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 315                                  SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 316                                                                              SubstratePassivation:BilayerPackingAndEquilibartion:PDBCleanup:push_filepad
# 317                                                       SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_filepad
# 318                                                       SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_infiles
#
#      nmolecules      shape                    earliest  \
# 0          1944  cylinders  2020-10-13 23:31:58.871647
# 1          1944  cylinders  2020-10-13 23:31:58.866984
# 2          1944  cylinders  2020-10-13 23:31:58.866854
# 3          1944  cylinders  2020-10-13 23:31:58.866480
# 4          1944  cylinders  2020-10-13 23:31:58.866236
# ..          ...        ...                         ...
# 314          81    bilayer  2020-10-13 23:31:57.793538
# 315          81    bilayer  2020-10-13 23:31:57.793400
# 316          81    bilayer  2020-10-13 23:31:57.793073
# 317          81    bilayer  2020-10-13 23:31:57.792866
# 318          81    bilayer                        None
#
#                          latest  object_count
# 0    2020-10-13 23:31:58.871696            21
# 1    2020-10-13 23:31:58.866987             2
# 2    2020-10-13 23:31:58.866857             2
# 3    2020-10-13 23:31:58.866480             1
# 4    2020-10-13 23:31:58.866236             1
# ..                          ...           ...
# 314  2020-10-13 23:31:57.793541             2
# 315  2020-10-13 23:31:57.793403             2
# 316  2020-10-13 23:31:57.793073             1
# 317  2020-10-13 23:31:57.792866             1
# 318                        None             1
#
# [319 rows x 6 columns]

# %%
parameters.keys()
# Out:
# dict_keys(['nmolecules', 'shape'])

# %%
res_df.set_index(list(parameters.keys()))
# Out:
#                                                                                                                                                                          step  \
# nmolecules shape
# 1944       cylinders  SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
#            cylinders                           SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
#            cylinders                              SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
#            cylinders                                                                          SubstratePassivation:CylindricalPackingAndEquilibartion:PDBCleanup:push_filepad
#            cylinders                                           SubstratePassivation:CylindricalPackingAndEquilibartion:CylindricalPacking:CylindricalPackingMain:push_filepad
# ...                                                                                                                                                                       ...
# 81         bilayer                                 SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
#            bilayer                                    SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
#            bilayer                                                                                SubstratePassivation:BilayerPackingAndEquilibartion:PDBCleanup:push_filepad
#            bilayer                                                         SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_filepad
#            bilayer                                                         SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_infiles
#
#                                         earliest                      latest  \
# nmolecules shape
# 1944       cylinders  2020-10-13 23:31:58.871647  2020-10-13 23:31:58.871696
#            cylinders  2020-10-13 23:31:58.866984  2020-10-13 23:31:58.866987
#            cylinders  2020-10-13 23:31:58.866854  2020-10-13 23:31:58.866857
#            cylinders  2020-10-13 23:31:58.866480  2020-10-13 23:31:58.866480
#            cylinders  2020-10-13 23:31:58.866236  2020-10-13 23:31:58.866236
# ...                                          ...                         ...
# 81         bilayer    2020-10-13 23:31:57.793538  2020-10-13 23:31:57.793541
#            bilayer    2020-10-13 23:31:57.793400  2020-10-13 23:31:57.793403
#            bilayer    2020-10-13 23:31:57.793073  2020-10-13 23:31:57.793073
#            bilayer    2020-10-13 23:31:57.792866  2020-10-13 23:31:57.792866
#            bilayer                          None                        None
#
#                       object_count
# nmolecules shape
# 1944       cylinders            21
#            cylinders             2
#            cylinders             2
#            cylinders             1
#            cylinders             1
# ...                            ...
# 81         bilayer               2
#            bilayer               2
#            bilayer               1
#            bilayer               1
#            bilayer               1
#
# [319 rows x 4 columns]

# %%
pd.MultiIndex.from_frame()

# %%
res_df.pivot(index='step', columns='shape', values='object_count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-5a85bc489bab> in <module>
# ----> 1 res_df.pivot(index='step', columns='shape', values='object_count')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     448         else:
#     449             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 450     return indexed.unstack(columns)
#     451
#     452
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    3548         from pandas.core.reshape.reshape import unstack
#    3549
# -> 3550         return unstack(self, level, fill_value)
#    3551
#    3552     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     412         if is_extension_array_dtype(obj.dtype):
#     413             return _unstack_extension_series(obj, level, fill_value)
# --> 414         unstacker = _Unstacker(
#     415             obj.values,
#     416             obj.index,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     139
#     140         self._make_sorted_values_labels()
# --> 141         self._make_selectors()
#     142
#     143     def _make_sorted_values_labels(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     177
#     178         if mask.sum() < len(self.index):
# --> 179             raise ValueError("Index contains duplicate entries, cannot reshape")
#     180
#     181         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
res_df.multiply(*parameters.keys())
# Out:
#                                                                                                                                                                step  \
# nmolecules
# 1944        SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsEnergyMinimizationAfterSolvation:push_filepad
# 1944                                 SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 1944                                    SubstratePassivation:CylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 1944                                                                                SubstratePassivation:CylindricalPackingAndEquilibartion:PDBCleanup:push_filepad
# 1944                                                 SubstratePassivation:CylindricalPackingAndEquilibartion:CylindricalPacking:CylindricalPackingMain:push_filepad
# ...                                                                                                                                                             ...
# 81                                       SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsSolvate:push_filepad
# 81                                          SubstratePassivation:BilayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsPrep:push_filepad
# 81                                                                                      SubstratePassivation:BilayerPackingAndEquilibartion:PDBCleanup:push_filepad
# 81                                                               SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_filepad
# 81                                                               SubstratePassivation:BilayerPackingAndEquilibartion:BilayerPacking:LayeredPackingMain:push_infiles
#
#                 shape                    earliest                      latest  \
# nmolecules
# 1944        cylinders  2020-10-13 23:31:58.871647  2020-10-13 23:31:58.871696
# 1944        cylinders  2020-10-13 23:31:58.866984  2020-10-13 23:31:58.866987
# 1944        cylinders  2020-10-13 23:31:58.866854  2020-10-13 23:31:58.866857
# 1944        cylinders  2020-10-13 23:31:58.866480  2020-10-13 23:31:58.866480
# 1944        cylinders  2020-10-13 23:31:58.866236  2020-10-13 23:31:58.866236
# ...               ...                         ...                         ...
# 81            bilayer  2020-10-13 23:31:57.793538  2020-10-13 23:31:57.793541
# 81            bilayer  2020-10-13 23:31:57.793400  2020-10-13 23:31:57.793403
# 81            bilayer  2020-10-13 23:31:57.793073  2020-10-13 23:31:57.793073
# 81            bilayer  2020-10-13 23:31:57.792866  2020-10-13 23:31:57.792866
# 81            bilayer                        None                        None
#
#             object_count
# nmolecules
# 1944                  21
# 1944                   2
# 1944                   2
# 1944                   1
# 1944                   1
# ...                  ...
# 81                     2
# 81                     2
# 81                     1
# 81                     1
# 81                     1
#
# [319 rows x 5 columns]

# %% [markdown]
# ### Overview on objects in project

# %%
# queries to the data base are simple dictionaries
query = {
    'metadata.project': project_id,
}

# %%
# use underlying MongoDB functionality to check total number of documents matching query
fp.filepad.count_documents(query)
# Out:
# 2854

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'type': '$metadata.type',
                'name': '$metadata.name',
                #'step': '$metadata.step',
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['type', 'name', 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_df
# Out:
#                                    type                name  \
# 0                              run_file                 NaN
# 1                  compressed_traj_file                 NaN
# 2                       checkpoint_file                 NaN
# 3                            index_file                 NaN
# 4                              mp4_file                 NaN
# 5                  surfactant_tail_rmsd                 NaN
# 6                  surfactant_head_rmsd                 NaN
# 7                        substrate_rmsd                 NaN
# 8                       counterion_rmsd                 NaN
# 9   surfactant_tail_surfactant_tail_rdf                 NaN
# 10  surfactant_head_surfactant_tail_rdf                 NaN
# 11  surfactant_head_surfactant_head_rdf                 NaN
# 12        substrate_surfactant_tail_rdf                 NaN
# 13        substrate_surfactant_head_rdf                 NaN
# 14       counterion_surfactant_tail_rdf                 NaN
# 15       counterion_surfactant_head_rdf                 NaN
# 16             counterion_substrate_rdf                 NaN
# 17            counterion_counterion_rdf                 NaN
# 18                      trajectory_file                 NaN
# 19                          energy_file                 NaN
# 20                             log_file                 NaN
# 21                        topology_file                 NaN
# 22                             png_file                 NaN
# 23                            data_file                 NaN
# 24                                input     renumber_png.sh
# 25                                input     em_solvated.mdp
# 26                                input             nvt.mdp
# 27                                input    relax_z_only.mdp
# 28                      counterion_file            1_NA.pdb
# 29                                input    sys.top.template
# 30                             template   flat.inp.template
# 31                                input      npt_z_only.mdp
# 32                                input  movie.pml.template
# 33                      surfactant_file           1_SDS.pdb
#
#                       earliest                      latest  object_count
# 0   2020-09-14 19:40:24.772796  2020-09-14 19:40:25.498132            14
# 1   2020-09-14 19:40:24.772789  2020-09-14 19:40:25.498125            15
# 2   2020-09-14 19:40:24.772777  2020-09-14 19:40:25.543747            16
# 3   2020-09-14 19:40:24.750985  2020-09-14 19:40:26.964702            80
# 4   2020-09-14 19:40:24.740566  2020-09-14 19:40:26.998397           116
# 5   2020-09-14 19:40:24.740563  2020-09-14 19:40:26.998395           118
# 6   2020-09-14 19:40:24.740561  2020-09-14 19:40:26.998392           120
# 7   2020-09-14 19:40:24.740559  2020-09-14 19:40:26.998390           122
# 8   2020-09-14 19:40:24.740556  2020-09-14 19:40:26.998388           123
# 9   2020-09-14 19:40:24.740554  2020-09-14 19:40:26.998385           123
# 10  2020-09-14 19:40:24.740552  2020-09-14 19:40:26.998383           123
# 11  2020-09-14 19:40:24.740550  2020-09-14 19:40:26.998381           124
# 12  2020-09-14 19:40:24.740547  2020-09-14 19:40:26.998379           125
# 13  2020-09-14 19:40:24.740545  2020-09-14 19:40:26.998376           127
# 14  2020-09-14 19:40:24.740543  2020-09-14 19:40:26.998374           128
# 15  2020-09-14 19:40:24.740540  2020-09-14 19:40:26.998372           128
# 16  2020-09-14 19:40:24.740538  2020-09-14 19:40:26.998369           130
# 17  2020-09-14 19:40:24.740536  2020-09-14 19:40:26.998367           135
# 18  2020-09-14 19:40:24.740529  2020-09-14 19:40:26.998360           136
# 19  2020-09-14 19:40:24.740526  2020-09-14 19:40:26.998357           139
# 20  2020-09-14 19:40:24.740521  2020-09-14 19:40:26.998352           141
# 21  2020-09-14 19:40:24.729488  2020-09-14 19:40:26.998365           231
# 22  2020-09-14 19:40:24.728604  2020-09-14 19:40:24.728604             1
# 23  2020-09-14 19:40:24.649384  2020-09-14 19:40:26.998362           329
# 24                        None                        None             1
# 25                        None                        None             1
# 26                        None                        None             1
# 27                        None                        None             1
# 28                        None                        None             1
# 29                        None                        None             1
# 30                        None                        None             1
# 31                        None                        None             1
# 32                        None                        None             1
# 33                        None                        None             1

# %% [markdown]
# ### Overview on images by distinct steps

# %%
query = {
    'metadata.project': project_id,
    'metadata.type': 'png_file',
}

# %%
# use underlying MongoDB functionality to check total number of documents matching query
fp.filepad.count_documents(query)
# Out:
# 1

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'

aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'type': '$metadata.type',
                'name': '$metadata.name',
                'step': '$metadata.step',
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['step', 'type', 'name', 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_df
# Out:
#                                                                              step  \
# 0  SubstratePassivation:ComponentMeasures:SurfactantMoleculeMeasures:push_filepad
#
#        type  name                    earliest                      latest  \
# 0  png_file   NaN  2020-09-14 19:40:24.728604  2020-09-14 19:40:24.728604
#
#    object_count
# 0             1

# %%
res_df["step"][0]
# Out:
# 'SubstratePassivation:ComponentMeasures:SurfactantMoleculeMeasures:push_filepad'

# %% [markdown]
# ### Overview on objects in specific step

# %%
# queries to the data base are simple dictionaries
query = {
    'metadata.project': project_id,
    'metadata.step': {'$regex': 'GromacsNPTEquilibration:push_filepad'}
}

# %%
# use underlying MongoDB functionality to check total number of documents matching query
fp.filepad.count_documents(query)
# Out:
# 583

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'type': '$metadata.type',
                'name': '$metadata.name',
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['type', 'name', 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_df
# Out:
#                                    type  name                    earliest  \
# 0                              mp4_file   NaN  2020-09-14 19:40:24.761392
# 1                  surfactant_tail_rmsd   NaN  2020-09-14 19:40:24.761389
# 2                  surfactant_head_rmsd   NaN  2020-09-14 19:40:24.761387
# 3                        substrate_rmsd   NaN  2020-09-14 19:40:24.761385
# 4                       counterion_rmsd   NaN  2020-09-14 19:40:24.761383
# 5   surfactant_tail_surfactant_tail_rdf   NaN  2020-09-14 19:40:24.761380
# 6   surfactant_head_surfactant_tail_rdf   NaN  2020-09-14 19:40:24.761378
# 7   surfactant_head_surfactant_head_rdf   NaN  2020-09-14 19:40:24.761376
# 8         substrate_surfactant_tail_rdf   NaN  2020-09-14 19:40:24.761374
# 9         substrate_surfactant_head_rdf   NaN  2020-09-14 19:40:24.761372
# 10       counterion_surfactant_tail_rdf   NaN  2020-09-14 19:40:24.761369
# 11       counterion_surfactant_head_rdf   NaN  2020-09-14 19:40:24.761367
# 12             counterion_substrate_rdf   NaN  2020-09-14 19:40:24.761365
# 13            counterion_counterion_rdf   NaN  2020-09-14 19:40:24.761363
# 14                           index_file   NaN  2020-09-14 19:40:24.761361
# 15                        topology_file   NaN  2020-09-14 19:40:24.761358
# 16                            data_file   NaN  2020-09-14 19:40:24.761356
# 17                      trajectory_file   NaN  2020-09-14 19:40:24.761354
# 18                          energy_file   NaN  2020-09-14 19:40:24.761351
# 19                             log_file   NaN  2020-09-14 19:40:24.761346
#
#                         latest  object_count
# 0   2020-09-14 19:40:26.794411            28
# 1   2020-09-14 19:40:26.794409            28
# 2   2020-09-14 19:40:26.794407            28
# 3   2020-09-14 19:40:26.794404            28
# 4   2020-09-14 19:40:26.794402            28
# 5   2020-09-14 19:40:26.794400            28
# 6   2020-09-14 19:40:26.794397            28
# 7   2020-09-14 19:40:26.794395            29
# 8   2020-09-14 19:40:26.794393            29
# 9   2020-09-14 19:40:26.794391            29
# 10  2020-09-14 19:40:26.794389            29
# 11  2020-09-14 19:40:26.794386            29
# 12  2020-09-14 19:40:26.794384            30
# 13  2020-09-14 19:40:26.794382            30
# 14  2020-09-14 19:40:26.794380            30
# 15  2020-09-14 19:40:26.794377            30
# 16  2020-09-14 19:40:26.794375            30
# 17  2020-09-14 19:40:26.794373            30
# 18  2020-09-14 19:40:26.794370            31
# 19  2020-09-14 19:40:26.794365            31

# %% [markdown]
# ### Overview on specific objects in specific steps

# %%
# queries to the data base are simple dictionaries
query = {
    'metadata.project': project_id,
    'metadata.step': {'$regex': 'GromacsNPTEquilibration:push_filepad'},
    'metadata.type': 'log_file',
}

# %%
# use underlying MongoDB functionality to check total number of documents matching query
fp.filepad.count_documents(query)
# Out:
# 31

# %%
# check files degenerate by 'metadata.type' ad 'metadata.name'
aggregation_pipeline = [
    {
        "$match": query
    },
    {  # group by unique project id
        "$group": { 
            "_id": { 
                'step': '$metadata.step',
            },
            "object_count": {"$sum": 1}, # count matching data sets
            "earliest":  {'$min': '$metadata.datetime' },
            "latest":  {'$max': '$metadata.datetime' },
        },
    },
    {  # sort by earliest date, descending
        "$sort": { 
            "earliest": pymongo.DESCENDING,
        }
    }
]

cursor = fp.filepad.aggregate(aggregation_pipeline)

res = [ {**c['_id'], **c} for c in cursor]
columns = ['step', 'earliest', 'latest', 'object_count', '_id']
res_df = pd.DataFrame(data=res, columns=columns) # pandas Dataframe is just nice for printing in notebook
del res_df["_id"]

# %%
res_df
# Out:
#                                                                                                                                           step  \
# 0  SubstratePassivation:HemicylindricalPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:push_filepad
# 1        SubstratePassivation:MonolayerPackingAndEquilibartion:GromacsMinimizationEquilibrationRelaxation:GromacsNPTEquilibration:push_filepad
#
#                      earliest                      latest  object_count
# 0  2020-09-14 19:40:24.805409  2020-09-14 19:40:25.934700            10
# 1  2020-09-14 19:40:24.761346  2020-09-14 19:40:26.794365            21

# %% [markdown]
# ### Inspect specific file

# %%
metadata = fp.filepad.find_one(query)

# %%
metadata.keys()
# Out:
# dict_keys(['_id', 'identifier', 'original_file_name', 'original_file_path', 'metadata', 'compressed', 'gfs_id'])

# %%
metadata['gfs_id']
# Out:
# '5f603fd8cd1d380ee68ea86a'

# %%
content, doc = fp.get_file_by_id(metadata['gfs_id'])

# %%
print(content.decode())
# Out:
#                       :-) GROMACS - gmx mdrun, 2019.3 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2018, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2019.3
# Executable:   /gpfs/software/juwels/stages/2019a/software/GROMACS/2019.3-intel-2019a/bin/gmx_mpi
# Data prefix:  /gpfs/software/juwels/stages/2019a/software/GROMACS/2019.3-intel-2019a
# Working dir:  /p/scratch/chfr13/hoermann/fireworks/launchpad/block_2020-09-14-23-14-58-481785/launcher_2020-09-15-03-11-32-155706
# Process ID:   31533
# Command line:
#   gmx_mpi mdrun -deffnm default -v
#
# GROMACS version:    2019.3
# Precision:          single
# Memory model:       64 bit
# MPI library:        MPI
# OpenMP support:     enabled (GMX_OPENMP_MAX_THREADS = 64)
# GPU support:        CUDA
# SIMD instructions:  AVX_512
# FFT library:        Intel MKL
# RDTSCP usage:       enabled
# TNG support:        enabled
# Hwloc support:      hwloc-2.0.3
# Tracing support:    disabled
# C compiler:         /gpfs/software/juwels/stages/2019a/software/impi/2019.3.199-iccifort-2019.3.199-GCC-8.3.0/intel64/bin/mpiicc Intel 19.0.0.20190206
# C compiler flags:    -xCORE-AVX512 -qopt-zmm-usage=high   -mkl=sequential -O2 -xHost -ftz -fp-speculation=safe -fp-model source -fopenmp -mt_mpi -std=gnu99  -O3 -DNDEBUG -ip -funroll-all-loops -alias-const -ansi-alias -no-prec-div -fimf-domain-exclusion=14 -qoverride-limits
# C++ compiler:       /gpfs/software/juwels/stages/2019a/software/impi/2019.3.199-iccifort-2019.3.199-GCC-8.3.0/intel64/bin/mpiicpc Intel 19.0.0.20190206
# C++ compiler flags:  -xCORE-AVX512 -qopt-zmm-usage=high   -mkl=sequential -O2 -xHost -ftz -fp-speculation=safe -fp-model source -fopenmp -mt_mpi -std=c++11   -O3 -DNDEBUG -ip -funroll-all-loops -alias-const -ansi-alias -no-prec-div -fimf-domain-exclusion=14 -qoverride-limits
# CUDA compiler:      /gpfs/software/juwels/stages/2019a/software/CUDA/10.1.105/bin/nvcc nvcc: NVIDIA (R) Cuda compiler driver;Copyright (c) 2005-2019 NVIDIA Corporation;Built on Fri_Feb__8_19:08:17_PST_2019;Cuda compilation tools, release 10.1, V10.1.105
# CUDA compiler flags:-gencode;arch=compute_30,code=sm_30;-gencode;arch=compute_35,code=sm_35;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_52,code=sm_52;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=compute_75;-use_fast_math;;-std=c++11;
# CUDA driver:        10.10
# CUDA runtime:       N/A
#
# NOTE: Detection of GPUs failed. The API reported:
#       no CUDA-capable device is detected
#       GROMACS cannot run tasks on a GPU.
#
# Running on 1 node with total 48 cores, 96 logical cores, 0 compatible GPUs
# Hardware detected on host jwc06n265.adm06.juwels.fzj.de (the node of MPI rank 0):
#   CPU info:
#     Vendor: Intel
#     Brand:  Intel(R) Xeon(R) Platinum 8168 CPU @ 2.70GHz
#     Family: 6   Model: 85   Stepping: 4
#     Features: aes apic avx avx2 avx512f avx512cd avx512bw avx512vl clfsh cmov cx8 cx16 f16c fma hle htt intel lahf mmx msr nonstop_tsc pcid pclmuldq pdcm pdpe1gb popcnt pse rdrnd rdtscp rtm sse2 sse3 sse4.1 sse4.2 ssse3 tdt x2apic
#     Number of AVX-512 FMA units: 2
#   Hardware topology: Full, with devices
#     Sockets, cores, and logical processors:
#       Socket  0: [   0  48] [   1  49] [   2  50] [   3  51] [   4  52] [   5  53] [   6  54] [   7  55] [   8  56] [   9  57] [  10  58] [  11  59] [  12  60] [  13  61] [  14  62] [  15  63] [  16  64] [  17  65] [  18  66] [  19  67] [  20  68] [  21  69] [  22  70] [  23  71]
#       Socket  1: [  24  72] [  25  73] [  26  74] [  27  75] [  28  76] [  29  77] [  30  78] [  31  79] [  32  80] [  33  81] [  34  82] [  35  83] [  36  84] [  37  85] [  38  86] [  39  87] [  40  88] [  41  89] [  42  90] [  43  91] [  44  92] [  45  93] [  46  94] [  47  95]
#     Numa nodes:
#       Node  0 (48815034368 bytes mem):   0  48   1  49   2  50   3  51   4  52   5  53   6  54   7  55   8  56   9  57  10  58  11  59  12  60  13  61  14  62  15  63  16  64  17  65  18  66  19  67  20  68  21  69  22  70  23  71
#       Node  1 (50709700608 bytes mem):  24  72  25  73  26  74  27  75  28  76  29  77  30  78  31  79  32  80  33  81  34  82  35  83  36  84  37  85  38  86  39  87  40  88  41  89  42  90  43  91  44  92  45  93  46  94  47  95
#       Latency:
#                0     1
#          0  1.00  2.10
#          1  2.10  1.00
#     Caches:
#       L1: 32768 bytes, linesize 64 bytes, assoc. 8, shared 2 ways
#       L2: 1048576 bytes, linesize 64 bytes, assoc. 16, shared 2 ways
#       L3: 34603008 bytes, linesize 64 bytes, assoc. 11, shared 48 ways
#     PCI devices:
#       0000:00:11.5  Id: 8086:a1d2  Class: 0x0106  Numa: 0
#       0000:00:17.0  Id: 8086:a182  Class: 0x0106  Numa: 0
#       0000:02:00.0  Id: 102b:0522  Class: 0x0300  Numa: 0
#       0000:37:00.0  Id: 8086:37ce  Class: 0x0200  Numa: 0
#       0000:37:00.1  Id: 8086:37ce  Class: 0x0200  Numa: 0
#       0000:37:00.2  Id: 8086:37d1  Class: 0x0200  Numa: 0
#       0000:37:00.3  Id: 8086:37d1  Class: 0x0200  Numa: 0
#       0000:5b:00.0  Id: 15b3:1013  Class: 0x0207  Numa: 0
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# M. J. Abraham, T. Murtola, R. Schulz, S. Páll, J. C. Smith, B. Hess, E.
# Lindahl
# GROMACS: High performance molecular simulations through multi-level
# parallelism from laptops to supercomputers
# SoftwareX 1 (2015) pp. 19-25
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# S. Páll, M. J. Abraham, C. Kutzner, B. Hess, E. Lindahl
# Tackling Exascale Software Challenges in Molecular Dynamics Simulations with
# GROMACS
# In S. Markidis & E. Laure (Eds.), Solving Software Challenges for Exascale 8759 (2015) pp. 3-27
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# S. Pronk, S. Páll, R. Schulz, P. Larsson, P. Bjelkmar, R. Apostolov, M. R.
# Shirts, J. C. Smith, P. M. Kasson, D. van der Spoel, B. Hess, and E. Lindahl
# GROMACS 4.5: a high-throughput and highly parallel open source molecular
# simulation toolkit
# Bioinformatics 29 (2013) pp. 845-54
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# B. Hess and C. Kutzner and D. van der Spoel and E. Lindahl
# GROMACS 4: Algorithms for highly efficient, load-balanced, and scalable
# molecular simulation
# J. Chem. Theory Comput. 4 (2008) pp. 435-447
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# D. van der Spoel, E. Lindahl, B. Hess, G. Groenhof, A. E. Mark and H. J. C.
# Berendsen
# GROMACS: Fast, Flexible and Free
# J. Comp. Chem. 26 (2005) pp. 1701-1719
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# E. Lindahl and B. Hess and D. van der Spoel
# GROMACS 3.0: A package for molecular simulation and trajectory analysis
# J. Mol. Mod. 7 (2001) pp. 306-317
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# H. J. C. Berendsen, D. van der Spoel and R. van Drunen
# GROMACS: A message-passing parallel molecular dynamics implementation
# Comp. Phys. Comm. 91 (1995) pp. 43-56
# -------- -------- --- Thank You --- -------- --------
#
#
# ++++ PLEASE CITE THE DOI FOR THIS VERSION OF GROMACS ++++
# https://doi.org/10.5281/zenodo.3243833
# -------- -------- --- Thank You --- -------- --------
#
#
# The number of OpenMP threads was set by environment variable OMP_NUM_THREADS to 1
#
# Multiple energy groups is not implemented for GPUs, falling back to the CPU. For better performance, run on the GPU without energy groups and then do gmx mdrun -rerun option on the trajectory with an energy group .tpr file.
# Input Parameters:
#    integrator                     = md
#    tinit                          = 0
#    dt                             = 0.002
#    nsteps                         = 50000
#    init-step                      = 0
#    simulation-part                = 1
#    comm-mode                      = Linear
#    nstcomm                        = 100
#    bd-fric                        = 0
#    ld-seed                        = 1881927982
#    emtol                          = 10
#    emstep                         = 0.01
#    niter                          = 20
#    fcstep                         = 0
#    nstcgsteep                     = 1000
#    nbfgscorr                      = 10
#    rtpi                           = 0.05
#    nstxout                        = 500
#    nstvout                        = 500
#    nstfout                        = 500
#    nstlog                         = 500
#    nstcalcenergy                  = 100
#    nstenergy                      = 500
#    nstxout-compressed             = 500
#    compressed-x-precision         = 1000
#    cutoff-scheme                  = Verlet
#    nstlist                        = 10
#    ns-type                        = Grid
#    pbc                            = xyz
#    periodic-molecules             = false
#    verlet-buffer-tolerance        = 0.005
#    rlist                          = 1.2
#    coulombtype                    = PME
#    coulomb-modifier               = Potential-shift
#    rcoulomb-switch                = 0
#    rcoulomb                       = 1.2
#    epsilon-r                      = 1
#    epsilon-rf                     = inf
#    vdw-type                       = Cut-off
#    vdw-modifier                   = Force-switch
#    rvdw-switch                    = 1
#    rvdw                           = 1.2
#    DispCorr                       = No
#    table-extension                = 1
#    fourierspacing                 = 0.16
#    fourier-nx                     = 96
#    fourier-ny                     = 96
#    fourier-nz                     = 208
#    pme-order                      = 4
#    ewald-rtol                     = 1e-05
#    ewald-rtol-lj                  = 0.001
#    lj-pme-comb-rule               = Geometric
#    ewald-geometry                 = 0
#    epsilon-surface                = 0
#    tcoupl                         = V-rescale
#    nsttcouple                     = 10
#    nh-chain-length                = 0
#    print-nose-hoover-chain-variables = false
#    pcoupl                         = Berendsen
#    pcoupltype                     = Anisotropic
#    nstpcouple                     = 1
#    tau-p                          = 2
#    compressibility (3x3):
#       compressibility[    0]={ 0.00000e+00,  0.00000e+00,  0.00000e+00}
#       compressibility[    1]={ 0.00000e+00,  0.00000e+00,  0.00000e+00}
#       compressibility[    2]={ 0.00000e+00,  0.00000e+00,  4.50000e-05}
#    ref-p (3x3):
#       ref-p[    0]={ 1.01300e+00,  0.00000e+00,  0.00000e+00}
#       ref-p[    1]={ 0.00000e+00,  1.01300e+00,  0.00000e+00}
#       ref-p[    2]={ 0.00000e+00,  0.00000e+00,  1.01300e+00}
#    refcoord-scaling               = No
#    posres-com (3):
#       posres-com[0]= 0.00000e+00
#       posres-com[1]= 0.00000e+00
#       posres-com[2]= 0.00000e+00
#    posres-comB (3):
#       posres-comB[0]= 0.00000e+00
#       posres-comB[1]= 0.00000e+00
#       posres-comB[2]= 0.00000e+00
#    QMMM                           = false
#    QMconstraints                  = 0
#    QMMMscheme                     = 0
#    MMChargeScaleFactor            = 1
# qm-opts:
#    ngQM                           = 0
#    constraint-algorithm           = Lincs
#    continuation                   = true
#    Shake-SOR                      = false
#    shake-tol                      = 0.0001
#    lincs-order                    = 4
#    lincs-iter                     = 1
#    lincs-warnangle                = 30
#    nwall                          = 0
#    wall-type                      = 9-3
#    wall-r-linpot                  = -1
#    wall-atomtype[0]               = -1
#    wall-atomtype[1]               = -1
#    wall-density[0]                = 0
#    wall-density[1]                = 0
#    wall-ewald-zfac                = 3
#    pull                           = false
#    awh                            = false
#    rotation                       = false
#    interactiveMD                  = false
#    disre                          = No
#    disre-weighting                = Conservative
#    disre-mixed                    = false
#    dr-fc                          = 1000
#    dr-tau                         = 0
#    nstdisreout                    = 100
#    orire-fc                       = 0
#    orire-tau                      = 0
#    nstorireout                    = 100
#    free-energy                    = no
#    cos-acceleration               = 0
#    deform (3x3):
#       deform[    0]={ 0.00000e+00,  0.00000e+00,  0.00000e+00}
#       deform[    1]={ 0.00000e+00,  0.00000e+00,  0.00000e+00}
#       deform[    2]={ 0.00000e+00,  0.00000e+00,  0.00000e+00}
#    simulated-tempering            = false
#    swapcoords                     = no
#    userint1                       = 0
#    userint2                       = 0
#    userint3                       = 0
#    userint4                       = 0
#    userreal1                      = 0
#    userreal2                      = 0
#    userreal3                      = 0
#    userreal4                      = 0
#    applied-forces:
#      electric-field:
#        x:
#          E0                       = 0
#          omega                    = 0
#          t0                       = 0
#          sigma                    = 0
#        y:
#          E0                       = 0
#          omega                    = 0
#          t0                       = 0
#          sigma                    = 0
#        z:
#          E0                       = 0
#          omega                    = 0
#          t0                       = 0
#          sigma                    = 0
# grpopts:
#    nrdf:      786827      589677
#    ref-t:      298.15           0
#    tau-t:           1           1
# annealing:          No          No
# annealing-npoints:           0           0
#    acc:	           0           0           0
#    nfreeze:           N           N           N
#    energygrp-flags[  0]: 0 0 0 0
#    energygrp-flags[  1]: 0 0 0 0
#    energygrp-flags[  2]: 0 0 0 0
#    energygrp-flags[  3]: 0 0 0 0
#
# Changing nstlist from 10 to 100, rlist from 1.2 to 1.275
#
#
# Initializing Domain Decomposition on 96 ranks
# Dynamic load balancing: locked
# Using update groups, nr 327961, average size 1.8 atoms, max. radius 0.139 nm
# Minimum cell size due to atom displacement: 0.683 nm
# Initial maximum distances in bonded interactions:
#     two-body bonded interactions: 0.416 nm, LJ-14, atoms 204552 204561
#   multi-body bonded interactions: 0.416 nm, Proper Dih., atoms 204552 204561
# Minimum cell size due to bonded interactions: 0.458 nm
# Guess for relative PME load: 0.18
# Will use 72 particle-particle and 24 PME only ranks
# This is a guess, check the performance at the end of the log file
# Using 24 separate PME ranks, as guessed by mdrun
# Scaling the initial minimum size with 1/0.8 (option -dds) = 1.25
# Optimizing the DD grid for 72 cells with a minimum initial size of 0.854 nm
# The maximum allowed number of cells is: X 17 Y 17 Z 38
# Domain decomposition grid 6 x 4 x 3, separate PME ranks 24
# PME domain decomposition: 6 x 4 x 1
# Interleaving PP and PME ranks
# This rank does only particle-particle work.
# Domain decomposition rank 0, coordinates 0 0 0
#
# The initial number of communication pulses is: X 1 Y 1 Z 1
# The initial domain decomposition cell size is: X 2.50 nm Y 3.74 nm Z 10.94 nm
#
# The maximum allowed distance for atom groups involved in interactions is:
#                  non-bonded interactions           1.553 nm
# (the following are initial values, they could change due to box deformation)
#             two-body bonded interactions  (-rdd)   1.553 nm
#           multi-body bonded interactions  (-rdd)   1.553 nm
#
# When dynamic load balancing gets turned on, these settings will change to:
# The maximum number of communication pulses is: X 1 Y 1 Z 1
# The minimum size for domain decomposition cells is 1.553 nm
# The requested allowed shrink of DD cells (option -dds) is: 0.80
# The allowed shrink of domain decomposition cells is: X 0.62 Y 0.41 Z 0.14
# The maximum allowed distance for atom groups involved in interactions is:
#                  non-bonded interactions           1.553 nm
#             two-body bonded interactions  (-rdd)   1.553 nm
#           multi-body bonded interactions  (-rdd)   1.553 nm
#
# Using 96 MPI processes
# Using 1 OpenMP thread per MPI process
#
#
# Non-default thread affinity set probably by the OpenMP library,
# disabling internal thread affinity
# System total charge: 0.000
# Will do PME sum in reciprocal space for electrostatic interactions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# U. Essmann, L. Perera, M. L. Berkowitz, T. Darden, H. Lee and L. G. Pedersen
# A smooth particle mesh Ewald method
# J. Chem. Phys. 103 (1995) pp. 8577-8592
# -------- -------- --- Thank You --- -------- --------
#
# Using a Gaussian width (1/beta) of 0.384195 nm for Ewald
# Potential shift: LJ r^-12: -2.648e-01 r^-6: -5.349e-01, Ewald -8.333e-06
# Initialized non-bonded Ewald correction tables, spacing: 1.02e-03 size: 1176
#
# Generated table with 1137 data points for 1-4 COUL.
# Tabscale = 500 points/nm
# Generated table with 1137 data points for 1-4 LJ6.
# Tabscale = 500 points/nm
# Generated table with 1137 data points for 1-4 LJ12.
# Tabscale = 500 points/nm
#
# Using SIMD 4x8 nonbonded short-range kernels
#
# Using a dual 4x8 pair-list setup updated with dynamic pruning:
#   outer list: updated every 100 steps, buffer 0.075 nm, rlist 1.275 nm
#   inner list: updated every  27 steps, buffer 0.001 nm, rlist 1.201 nm
# At tolerance 0.005 kJ/mol/ps per atom, equivalent classical 1x1 list would be:
#   outer list: updated every 100 steps, buffer 0.235 nm, rlist 1.435 nm
#   inner list: updated every  27 steps, buffer 0.100 nm, rlist 1.300 nm
#
#
# Initializing LINear Constraint Solver
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# B. Hess and H. Bekker and H. J. C. Berendsen and J. G. E. M. Fraaije
# LINCS: A Linear Constraint Solver for molecular simulations
# J. Comp. Chem. 18 (1997) pp. 1463-1472
# -------- -------- --- Thank You --- -------- --------
#
# The number of constraints is 9850
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# S. Miyamoto and P. A. Kollman
# SETTLE: An Analytical Version of the SHAKE and RATTLE Algorithms for Rigid
# Water Models
# J. Comp. Chem. 13 (1992) pp. 952-962
# -------- -------- --- Thank You --- -------- --------
#
#
# Linking all bonded interactions to atoms
#
#
# Intra-simulation communication will occur every 1 steps.
# Center of mass motion removal mode is Linear
# We have the following groups for center of mass motion removal:
#   0:  non-Substrate
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# G. Bussi, D. Donadio and M. Parrinello
# Canonical sampling through velocity rescaling
# J. Chem. Phys. 126 (2007) pp. 014101
# -------- -------- --- Thank You --- -------- --------
#
# There are: 586429 Atoms
# Atom distribution over 72 domains: av 8144 stddev 1528 min 5877 max 9559
#
# Started mdrun on rank 0 Tue Sep 15 05:12:14 2020
#
#            Step           Time
#               0        0.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.01942e+03    6.26633e+04    1.55748e+04    4.06446e+03    1.00041e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.38198e+07   -5.92912e+06    1.96678e+04    0.00000e+00   -3.95399e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.81096e+05   -3.85588e+07   -3.85580e+07    1.71447e+02    1.19302e+04
#    Constr. rmsd
#     6.18561e-06
#
#
# DD  step 99 load imb.: force 23.3%  pme mesh/force 0.402
#
# step 300 Turning on dynamic load balancing, because the performance loss due to load imbalance is 17.2 %.
#
# DD  step 499  vol min/aver 0.883  load imb.: force 20.9%  pme mesh/force 0.390
#            Step           Time
#             500        1.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.86204e+03    6.25991e+04    1.51657e+04    4.08547e+03    1.00164e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.49861e+07   -5.93124e+06    1.96027e+04    3.85579e+04   -4.06703e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.46914e+06   -3.92012e+07   -3.85536e+07    2.56734e+02   -9.44663e+02
#    Constr. rmsd
#     6.14222e-06
#
#
# DD  step 999  vol min/aver 0.616  load imb.: force 10.8%  pme mesh/force 0.380
#            Step           Time
#            1000        2.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.06324e+03    6.27743e+04    1.51820e+04    3.86765e+03    9.97765e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.51787e+07   -5.92886e+06    1.93991e+04    3.59280e+04   -4.08636e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.27570e+06   -3.95879e+07   -3.85527e+07    2.22930e+02   -2.64000e+03
#    Constr. rmsd
#     6.08458e-06
#
#
# DD  step 1499  vol min/aver 0.493  load imb.: force 10.5%  pme mesh/force 0.386
#            Step           Time
#            1500        3.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.77336e+03    6.24621e+04    1.52453e+04    4.05610e+03    9.99927e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.52945e+07   -5.92714e+06    1.94059e+04    3.45185e+04   -4.09792e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.15683e+06   -3.98223e+07   -3.85523e+07    2.02156e+02   -3.48997e+03
#    Constr. rmsd
#     6.12132e-06
#
#
# DD  step 1999  vol min/aver 0.424  load imb.: force 12.1%  pme mesh/force 0.411
#            Step           Time
#            2000        4.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.17291e+03    6.15042e+04    1.50916e+04    3.97775e+03    9.99505e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.53593e+07   -5.93182e+06    1.94068e+04    3.39105e+04   -4.10501e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.08393e+06   -3.99661e+07   -3.85518e+07    1.89417e+02   -4.09275e+03
#    Constr. rmsd
#     6.14864e-06
#
#
# DD  step 2499  vol min/aver 0.361  load imb.: force 16.3%  pme mesh/force 0.581
#            Step           Time
#            2500        5.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.05675e+03    6.22232e+04    1.50895e+04    3.86148e+03    9.99808e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54021e+07   -5.93258e+06    1.90431e+04    3.36441e+04   -4.10938e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.04047e+06   -4.00533e+07   -3.85515e+07    1.81823e+02   -4.50850e+03
#    Constr. rmsd
#     6.13439e-06
#
#
# DD  step 2999  vol min/aver 0.395  load imb.: force 11.7%  pme mesh/force 0.492
#            Step           Time
#            3000        6.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.06680e+03    6.22557e+04    1.50960e+04    3.78578e+03    9.96753e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54288e+07   -5.93261e+06    1.93495e+04    3.31636e+04   -4.11211e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.01590e+06   -4.01052e+07   -3.85517e+07    1.77529e+02   -4.61426e+03
#    Constr. rmsd
#     6.11332e-06
#
#
# DD  step 3499  vol min/aver 0.457  load imb.: force 13.6%  pme mesh/force 0.403
#            Step           Time
#            3500        7.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.05471e+03    6.18994e+04    1.48969e+04    3.88472e+03    1.00066e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54426e+07   -5.93586e+06    1.90798e+04    3.30388e+04   -4.11385e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     1.00060e+06   -4.01379e+07   -3.85511e+07    1.74855e+02   -4.85698e+03
#    Constr. rmsd
#     6.13418e-06
#
#
# DD  step 3999  vol min/aver 0.529  load imb.: force 17.4%  pme mesh/force 0.963
#            Step           Time
#            4000        8.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.88798e+03    6.23335e+04    1.49947e+04    3.72812e+03    9.99615e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54548e+07   -5.93623e+06    1.93764e+04    3.30313e+04   -4.11507e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.90760e+05   -4.01599e+07   -3.85518e+07    1.73136e+02   -4.86237e+03
#    Constr. rmsd
#     6.14669e-06
#
# step 4400: timed with pme grid 96 96 208, coulomb cutoff 1.200: 4078.1 M-cycles
#
# DD  step 4499  vol min/aver 0.633  load imb.: force  5.9%  pme mesh/force 0.778
#            Step           Time
#            4500        9.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.84074e+03    6.19358e+04    1.48396e+04    3.96216e+03    1.00086e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54616e+07   -5.92884e+06    1.37792e+04    3.29472e+04   -4.11560e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.83304e+05   -4.01727e+07   -3.85521e+07    1.71833e+02   -4.91514e+03
#    Constr. rmsd
#     5.99095e-06
#
# step 4600: timed with pme grid 84 84 192, coulomb cutoff 1.338: 4595.4 M-cycles
# step 4800: timed with pme grid 96 96 192, coulomb cutoff 1.282: 4079.6 M-cycles
# step 5000: timed with pme grid 96 96 200, coulomb cutoff 1.231: 5405.6 M-cycles
#
# DD  step 4999  vol min/aver 0.664  load imb.: force  8.2%  pme mesh/force 0.393
#            Step           Time
#            5000       10.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.00702e+03    6.16541e+04    1.49605e+04    3.85383e+03    9.99902e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54657e+07   -5.93309e+06    1.91493e+04    3.28240e+04   -4.11594e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.79365e+05   -4.01800e+07   -3.85521e+07    1.71145e+02   -4.96641e+03
#    Constr. rmsd
#     6.18525e-06
#
# step 5200: timed with pme grid 96 96 208, coulomb cutoff 1.200: 5367.1 M-cycles
#               optimal pme grid 96 96 208, coulomb cutoff 1.200
#
# DD  step 5499  vol min/aver 0.576  load imb.: force 13.5%  pme mesh/force 0.428
#            Step           Time
#            5500       11.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.02305e+03    6.14580e+04    1.50048e+04    3.89260e+03    9.99441e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54684e+07   -5.93644e+06    1.93401e+04    3.27078e+04   -4.11655e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.80323e+05   -4.01852e+07   -3.85518e+07    1.71312e+02   -4.93311e+03
#    Constr. rmsd
#     6.12031e-06
#
#
# DD  step 5999  vol min/aver 0.571  load imb.: force 12.3%  pme mesh/force 0.422
#            Step           Time
#            6000       12.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.10433e+03    6.12395e+04    1.49429e+04    3.81911e+03    9.98728e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54672e+07   -5.93329e+06    1.91976e+04    3.27185e+04   -4.11615e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.77555e+05   -4.01840e+07   -3.85517e+07    1.70828e+02   -4.90635e+03
#    Constr. rmsd
#     5.97287e-06
#
#
# DD  step 6499  vol min/aver 0.529  load imb.: force 14.8%  pme mesh/force 0.398
#            Step           Time
#            6500       13.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.99421e+03    6.14257e+04    1.49033e+04    3.77974e+03    9.99442e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54680e+07   -5.93572e+06    1.91217e+04    3.28834e+04   -4.11647e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.76651e+05   -4.01880e+07   -3.85513e+07    1.70670e+02   -5.01721e+03
#    Constr. rmsd
#     6.09606e-06
#
#
# DD  step 6999  vol min/aver 0.514  load imb.: force 14.8%  pme mesh/force 0.405
#            Step           Time
#            7000       14.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.11769e+03    6.11696e+04    1.49839e+04    3.81606e+03    9.99789e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54698e+07   -5.93342e+06    1.92412e+04    3.26494e+04   -4.11643e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74610e+05   -4.01897e+07   -3.85513e+07    1.70314e+02   -4.94974e+03
#    Constr. rmsd
#     6.10510e-06
#
#
# DD  step 7499  vol min/aver 0.537  load imb.: force 11.0%  pme mesh/force 0.458
#            Step           Time
#            7500       15.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     7.11539e+03    6.12053e+04    1.47741e+04    3.84534e+03    1.00120e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54663e+07   -5.93801e+06    1.94839e+04    3.28915e+04   -4.11649e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75276e+05   -4.01896e+07   -3.85513e+07    1.70430e+02   -4.94852e+03
#    Constr. rmsd
#     6.00565e-06
#
#
# DD  step 7999  vol min/aver 0.553  load imb.: force 14.9%  pme mesh/force 0.661
#
# step 8000 Turning off dynamic load balancing, because it is degrading performance.
# Atom distribution over 72 domains: av 8144 stddev 1461 min 5973 max 9533
#            Step           Time
#            8000       16.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.68517e+03    6.13062e+04    1.48260e+04    3.68696e+03    9.97703e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54747e+07   -5.93411e+06    1.91894e+04    3.27604e+04   -4.11706e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.72176e+05   -4.01984e+07   -3.85550e+07    1.69888e+02   -4.99443e+03
#    Constr. rmsd
#     6.10264e-06
#
#
# DD  step 8499 load imb.: force 22.3%  pme mesh/force 0.402
#            Step           Time
#            8500       17.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.79927e+03    6.14017e+04    1.48862e+04    3.80838e+03    9.98254e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54734e+07   -5.93535e+06    1.92121e+04    3.27755e+04   -4.11700e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.73387e+05   -4.01966e+07   -3.85549e+07    1.70100e+02   -4.92604e+03
#    Constr. rmsd
#     6.15298e-06
#
#
# DD  step 8999 load imb.: force 22.5%  pme mesh/force 0.408
#            Step           Time
#            9000       18.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.81431e+03    6.08425e+04    1.49263e+04    3.80794e+03    9.99236e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54755e+07   -5.93427e+06    1.94427e+04    3.28221e+04   -4.11712e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75688e+05   -4.01955e+07   -3.85549e+07    1.70502e+02   -4.96786e+03
#    Constr. rmsd
#     6.08521e-06
#
#
# DD  step 9499 load imb.: force 22.7%  pme mesh/force 0.393
#            Step           Time
#            9500       19.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.72951e+03    6.13570e+04    1.47476e+04    3.75749e+03    9.98044e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54761e+07   -5.93422e+06    1.93966e+04    3.28417e+04   -4.11716e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75860e+05   -4.01958e+07   -3.85549e+07    1.70532e+02   -4.98158e+03
#    Constr. rmsd
#     5.88288e-06
#
#
# DD  step 9999 load imb.: force 22.3%  pme mesh/force 0.378
#            Step           Time
#           10000       20.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.82229e+03    6.06657e+04    1.47802e+04    3.78217e+03    9.99278e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54736e+07   -5.93541e+06    1.92443e+04    3.27981e+04   -4.11710e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.76023e+05   -4.01950e+07   -3.85549e+07    1.70560e+02   -4.97375e+03
#    Constr. rmsd
#     6.00923e-06
#
#
# DD  step 10499 load imb.: force 22.4%  pme mesh/force 0.373
#            Step           Time
#           10500       21.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.67458e+03    6.07602e+04    1.44781e+04    3.69124e+03    1.00025e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54750e+07   -5.93283e+06    1.91929e+04    3.28486e+04   -4.11702e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75221e+05   -4.01950e+07   -3.85548e+07    1.70420e+02   -4.93889e+03
#    Constr. rmsd
#     6.07421e-06
#
#
# DD  step 10999 load imb.: force 22.7%  pme mesh/force 0.405
#            Step           Time
#           11000       22.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.60632e+03    6.09211e+04    1.48190e+04    3.74569e+03    9.97585e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54767e+07   -5.92812e+06    1.93200e+04    3.26960e+04   -4.11669e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.76270e+05   -4.01906e+07   -3.85547e+07    1.70604e+02   -4.95698e+03
#    Constr. rmsd
#     6.08419e-06
#
#
# DD  step 11499 load imb.: force 22.6%  pme mesh/force 0.396
#            Step           Time
#           11500       23.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.88017e+03    6.04075e+04    1.47915e+04    3.82210e+03    1.00009e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54742e+07   -5.93214e+06    1.93516e+04    3.27925e+04   -4.11683e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75301e+05   -4.01930e+07   -3.85547e+07    1.70434e+02   -4.95344e+03
#    Constr. rmsd
#     5.98778e-06
#
#
# DD  step 11999 load imb.: force 22.2%  pme mesh/force 0.406
#            Step           Time
#           12000       24.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.63955e+03    6.03183e+04    1.46914e+04    3.89019e+03    1.00004e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54757e+07   -5.93209e+06    1.95693e+04    3.26977e+04   -4.11700e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.76248e+05   -4.01937e+07   -3.85547e+07    1.70600e+02   -5.01414e+03
#    Constr. rmsd
#     6.04081e-06
#
#
# DD  step 12499 load imb.: force 22.5%  pme mesh/force 0.371
#            Step           Time
#           12500       25.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.53195e+03    6.01066e+04    1.47987e+04    3.89066e+03    1.00136e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54786e+07   -5.92811e+06    1.93979e+04    3.27820e+04   -4.11691e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75007e+05   -4.01941e+07   -3.85546e+07    1.70383e+02   -5.01449e+03
#    Constr. rmsd
#     6.05378e-06
#
#
# DD  step 12999 load imb.: force 22.5%  pme mesh/force 0.410
#            Step           Time
#           13000       26.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.59792e+03    5.97334e+04    1.47015e+04    3.92583e+03    1.00167e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54793e+07   -5.92801e+06    1.93506e+04    3.27238e+04   -4.11702e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.77300e+05   -4.01929e+07   -3.85546e+07    1.70784e+02   -4.95425e+03
#    Constr. rmsd
#     6.08821e-06
#
#
# DD  step 13499 load imb.: force 22.5%  pme mesh/force 0.407
#            Step           Time
#           13500       27.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.52656e+03    6.02353e+04    1.47133e+04    3.81886e+03    9.99981e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54779e+07   -5.93106e+06    1.95016e+04    3.26166e+04   -4.11716e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.78864e+05   -4.01927e+07   -3.85545e+07    1.71057e+02   -4.97749e+03
#    Constr. rmsd
#     5.99596e-06
#
#
# DD  step 13999 load imb.: force 22.4%  pme mesh/force 0.401
#            Step           Time
#           14000       28.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.80710e+03    5.97395e+04    1.45750e+04    3.88194e+03    1.00084e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54776e+07   -5.93251e+06    1.93835e+04    3.27656e+04   -4.11729e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74699e+05   -4.01982e+07   -3.85544e+07    1.70329e+02   -4.93789e+03
#    Constr. rmsd
#     5.96856e-06
#
#
# DD  step 14499 load imb.: force 22.4%  pme mesh/force 0.413
#            Step           Time
#           14500       29.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.36958e+03    5.97209e+04    1.45094e+04    3.87664e+03    1.00172e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54772e+07   -5.92941e+06    1.93068e+04    3.25317e+04   -4.11701e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.73841e+05   -4.01963e+07   -3.85544e+07    1.70179e+02   -4.95817e+03
#    Constr. rmsd
#     6.07071e-06
#
#
# DD  step 14999 load imb.: force 22.2%  pme mesh/force 0.403
#            Step           Time
#           15000       30.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.46922e+03    5.96556e+04    1.46204e+04    3.79506e+03    1.00203e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54778e+07   -5.93196e+06    1.92988e+04    3.28072e+04   -4.11729e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75514e+05   -4.01974e+07   -3.85544e+07    1.70472e+02   -5.00851e+03
#    Constr. rmsd
#     5.97594e-06
#
#
# DD  step 15499 load imb.: force 22.4%  pme mesh/force 0.414
#            Step           Time
#           15500       31.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.63821e+03    5.99022e+04    1.45817e+04    3.65353e+03    9.98624e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54779e+07   -5.92995e+06    1.94113e+04    3.27396e+04   -4.11711e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.73575e+05   -4.01975e+07   -3.85544e+07    1.70133e+02   -4.93301e+03
#    Constr. rmsd
#     6.00416e-06
#
#
# DD  step 15999 load imb.: force 27.8%  pme mesh/force 0.728
#            Step           Time
#           16000       32.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.52174e+03    5.96200e+04    1.45995e+04    3.80363e+03    1.00071e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54775e+07   -5.93215e+06    1.91076e+04    3.25260e+04   -4.11734e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.76583e+05   -4.01968e+07   -3.85543e+07    1.70658e+02   -5.01537e+03
#    Constr. rmsd
#     6.01528e-06
#
#
# DD  step 16499 load imb.: force 22.3%  pme mesh/force 0.374
#            Step           Time
#           16500       33.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.39561e+03    5.94966e+04    1.44759e+04    3.64505e+03    1.00000e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54805e+07   -5.92764e+06    1.94081e+04    3.28023e+04   -4.11719e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.76668e+05   -4.01953e+07   -3.85543e+07    1.70673e+02   -4.94155e+03
#    Constr. rmsd
#     5.99414e-06
#
#
# DD  step 16999 load imb.: force 22.1%  pme mesh/force 0.371
#            Step           Time
#           17000       34.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.49683e+03    5.91389e+04    1.45356e+04    3.80911e+03    1.00230e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54768e+07   -5.93004e+06    1.97409e+04    3.25947e+04   -4.11703e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74109e+05   -4.01962e+07   -3.85542e+07    1.70226e+02   -4.97628e+03
#    Constr. rmsd
#     6.05189e-06
#
#
# DD  step 17499 load imb.: force 22.2%  pme mesh/force 0.394
#            Step           Time
#           17500       35.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.39049e+03    5.96590e+04    1.47110e+04    3.70225e+03    9.97694e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54742e+07   -5.93622e+06    1.91675e+04    3.26852e+04   -4.11744e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75819e+05   -4.01986e+07   -3.85541e+07    1.70525e+02   -4.91377e+03
#    Constr. rmsd
#     5.86962e-06
#
#
# DD  step 17999 load imb.: force 22.3%  pme mesh/force 0.407
#            Step           Time
#           18000       36.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.50042e+03    5.94763e+04    1.43924e+04    3.69539e+03    9.98467e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54778e+07   -5.93136e+06    1.93746e+04    3.26382e+04   -4.11732e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74672e+05   -4.01985e+07   -3.85541e+07    1.70324e+02   -4.88846e+03
#    Constr. rmsd
#     5.94934e-06
#
#
# DD  step 18499 load imb.: force 22.4%  pme mesh/force 0.403
#            Step           Time
#           18500       37.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.54547e+03    5.91953e+04    1.45303e+04    3.70948e+03    9.98962e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54778e+07   -5.93332e+06    1.94077e+04    3.26896e+04   -4.11751e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74526e+05   -4.02006e+07   -3.85541e+07    1.70299e+02   -4.96189e+03
#    Constr. rmsd
#     5.94178e-06
#
#
# DD  step 18999 load imb.: force 22.2%  pme mesh/force 0.398
#            Step           Time
#           19000       38.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.48817e+03    5.90329e+04    1.45179e+04    3.80350e+03    1.00036e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54758e+07   -5.93329e+06    1.93069e+04    3.24951e+04   -4.11734e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.72153e+05   -4.02012e+07   -3.85540e+07    1.69884e+02   -4.96244e+03
#    Constr. rmsd
#     5.90716e-06
#
#
# DD  step 19499 load imb.: force 22.1%  pme mesh/force 0.404
#            Step           Time
#           19500       39.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.33473e+03    5.86174e+04    1.45467e+04    3.98348e+03    1.00488e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54760e+07   -5.93696e+06    1.93363e+04    3.25928e+04   -4.11770e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.73512e+05   -4.02035e+07   -3.85540e+07    1.70122e+02   -4.95041e+03
#    Constr. rmsd
#     5.93720e-06
#
#
# DD  step 19999 load imb.: force 22.2%  pme mesh/force 0.377
#
# step 20000 Turning on dynamic load balancing, because the performance loss due to load imbalance is 14.7 %.
#            Step           Time
#           20000       40.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.39839e+03    5.90767e+04    1.45794e+04    3.67356e+03    9.98877e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54793e+07   -5.93096e+06    1.93239e+04    3.25211e+04   -4.11748e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.77139e+05   -4.01976e+07   -3.85540e+07    1.70755e+02   -4.90804e+03
#    Constr. rmsd
#     5.92036e-06
#
#
# DD  step 20499  vol min/aver 0.684  load imb.: force 10.2%  pme mesh/force 0.417
#            Step           Time
#           20500       41.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.45108e+03    5.93202e+04    1.45104e+04    3.86367e+03    1.00063e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54747e+07   -5.92919e+06    1.92402e+04    3.25757e+04   -4.11678e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.77180e+05   -4.01906e+07   -3.85509e+07    1.70763e+02   -4.98759e+03
#    Constr. rmsd
#     5.96277e-06
#
#
# ...
#    Constr. rmsd
#     5.88109e-06
#
#
# DD  step 44999 load imb.: force 31.5%  pme mesh/force 0.846
#            Step           Time
#           45000       90.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.09345e+03    5.76759e+04    1.42356e+04    3.67428e+03    9.99041e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54803e+07   -5.93268e+06    1.95281e+04    3.25085e+04   -4.11793e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74115e+05   -4.02052e+07   -3.85513e+07    1.70227e+02   -4.92132e+03
#    Constr. rmsd
#     5.91132e-06
#
#
# DD  step 45499 load imb.: force 31.1%  pme mesh/force 0.843
#            Step           Time
#           45500       91.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     5.93948e+03    5.71717e+04    1.44379e+04    3.80384e+03    1.00314e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54741e+07   -5.93821e+06    1.92678e+04    3.24339e+04   -4.11789e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75093e+05   -4.02038e+07   -3.85512e+07    1.70398e+02   -4.93704e+03
#    Constr. rmsd
#     5.81559e-06
#
#
# DD  step 45999 load imb.: force 31.3%  pme mesh/force 0.866
#            Step           Time
#           46000       92.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.14199e+03    5.70932e+04    1.44267e+04    3.68786e+03    1.00109e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54773e+07   -5.93602e+06    1.96075e+04    3.25012e+04   -4.11797e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75611e+05   -4.02041e+07   -3.85512e+07    1.70488e+02   -4.94873e+03
#    Constr. rmsd
#     5.88098e-06
#
#
# DD  step 46499 load imb.: force 22.0%  pme mesh/force 0.402
#            Step           Time
#           46500       93.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.22621e+03    5.70313e+04    1.43947e+04    3.73551e+03    1.00144e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54773e+07   -5.93396e+06    1.94451e+04    3.24047e+04   -4.11779e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74622e+05   -4.02033e+07   -3.85511e+07    1.70316e+02   -4.93761e+03
#    Constr. rmsd
#     5.85222e-06
#
#
# DD  step 46999 load imb.: force 30.7%  pme mesh/force 0.848
#            Step           Time
#           47000       94.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.05597e+03    5.75921e+04    1.42345e+04    3.62632e+03    9.99864e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54733e+07   -5.93930e+06    1.94670e+04    3.25601e+04   -4.11791e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75210e+05   -4.02039e+07   -3.85511e+07    1.70418e+02   -4.89280e+03
#    Constr. rmsd
#     5.95943e-06
#
#
# DD  step 47499 load imb.: force 30.0%  pme mesh/force 0.863
#            Step           Time
#           47500       95.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.19306e+03    5.71724e+04    1.43060e+04    3.57520e+03    9.97735e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54725e+07   -5.94339e+06    1.92341e+04    3.24430e+04   -4.11832e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74746e+05   -4.02084e+07   -3.85510e+07    1.70337e+02   -4.89234e+03
#    Constr. rmsd
#     5.89151e-06
#
#
# DD  step 47999 load imb.: force 27.3%  pme mesh/force 0.713
#            Step           Time
#           48000       96.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.19228e+03    5.75871e+04    1.44810e+04    3.52655e+03    1.00050e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54778e+07   -5.93705e+06    1.94863e+04    3.24322e+04   -4.11811e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.73593e+05   -4.02075e+07   -3.85509e+07    1.70136e+02   -4.99181e+03
#    Constr. rmsd
#     5.79067e-06
#
#
# DD  step 48499 load imb.: force 21.9%  pme mesh/force 0.382
#            Step           Time
#           48500       97.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.11537e+03    5.73984e+04    1.43264e+04    3.75043e+03    1.00132e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54768e+07   -5.93883e+06    1.91840e+04    3.24658e+04   -4.11822e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74230e+05   -4.02080e+07   -3.85509e+07    1.70247e+02   -4.95092e+03
#    Constr. rmsd
#     5.79474e-06
#
#
# DD  step 48999 load imb.: force 21.8%  pme mesh/force 0.388
#            Step           Time
#           49000       98.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.10152e+03    5.69670e+04    1.43797e+04    3.67749e+03    1.00046e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54758e+07   -5.93938e+06    1.93708e+04    3.24373e+04   -4.11822e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.72986e+05   -4.02092e+07   -3.85509e+07    1.70030e+02   -4.93061e+03
#    Constr. rmsd
#     5.83884e-06
#
#
# DD  step 49499 load imb.: force 21.8%  pme mesh/force 0.402
#            Step           Time
#           49500       99.00000
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.14799e+03    5.71229e+04    1.44172e+04    3.62978e+03    1.00090e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54770e+07   -5.93775e+06    1.93341e+04    3.23550e+04   -4.11817e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.75071e+05   -4.02066e+07   -3.85508e+07    1.70394e+02   -4.91212e+03
#    Constr. rmsd
#     5.72661e-06
#
#
# DD  step 49999 load imb.: force 32.1%  pme mesh/force 0.867
#            Step           Time
#           50000      100.00000
#
# Writing checkpoint, step 50000 at Tue Sep 15 05:33:23 2020
#
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.25421e+03    5.75337e+04    1.44113e+04    3.75749e+03    1.00039e+05
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54777e+07   -5.93816e+06    1.91865e+04    3.24323e+04   -4.11823e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.74792e+05   -4.02075e+07   -3.85507e+07    1.70345e+02   -4.95061e+03
#    Constr. rmsd
#     5.71795e-06
#
# 	<======  ###############  ==>
# 	<====  A V E R A G E S  ====>
# 	<==  ###############  ======>
#
# 	Statistics over 50001 steps using 501 frames
#
#    Energies (kJ/mol)
#            Bond            U-B    Proper Dih.          LJ-14     Coulomb-14
#     6.42042e+03    5.91014e+04    1.45954e+04    3.75124e+03    9.99926e+04
#         LJ (SR)   Coulomb (SR)   Coul. recip. Position Rest.      Potential
#    -3.54568e+07   -5.93362e+06    1.93123e+04    3.27402e+04   -4.11545e+07
#     Kinetic En.   Total Energy  Conserved En.    Temperature Pressure (bar)
#     9.90502e+05   -4.01640e+07   -3.85527e+07    1.73091e+02   -4.79924e+03
#    Constr. rmsd
#     0.00000e+00
#
#           Box-X          Box-Y          Box-Z
#     1.49836e+01    1.49725e+01    3.27551e+01
#
#    Total Virial (kJ/mol)
#     1.74974e+06    1.80549e+03    1.29317e+03
#     1.80704e+03    2.09856e+06    2.03874e+03
#     1.30602e+03    2.00839e+03    3.27695e+05
#
#    Pressure (bar)
#    -6.42422e+03   -8.28403e+00   -5.87425e+00
#    -8.29111e+00   -7.99451e+03   -9.91769e+00
#    -5.93243e+00   -9.78044e+00    2.09963e+01
#
#   Epot (kJ/mol)        Coul-SR          LJ-SR        Coul-14          LJ-14
# Surfactant-Surfactant   -8.23081e+04   -1.72357e+04    9.99926e+04    3.75124e+03
# Surfactant-Substrate    0.00000e+00   -1.71995e+04    0.00000e+00    0.00000e+00
#  Surfactant-Ion   -3.05524e+04    1.28909e+03    0.00000e+00    0.00000e+00
# Surfactant-rest   -1.00614e+05   -1.30442e+04    0.00000e+00    0.00000e+00
# Substrate-Substrate    0.00000e+00   -3.58666e+07    0.00000e+00    0.00000e+00
#   Substrate-Ion    0.00000e+00   -5.18288e+01    0.00000e+00    0.00000e+00
#  Substrate-rest    0.00000e+00   -1.21071e+05    0.00000e+00    0.00000e+00
#         Ion-Ion   -7.55485e+04   -4.26654e+00    0.00000e+00    0.00000e+00
#        Ion-rest   -1.56717e+05    1.60960e+04    0.00000e+00    0.00000e+00
#       rest-rest   -5.48788e+06    5.60975e+05    0.00000e+00    0.00000e+00
#
# T-non-Substrate    T-Substrate
#     2.95273e+02    1.00587e+01
#
#
# 	M E G A - F L O P S   A C C O U N T I N G
#
#  NB=Group-cutoff nonbonded kernels    NxN=N-by-N cluster Verlet kernels
#  RF=Reaction-Field  VdW=Van der Waals  QSTab=quadratic-spline table
#  W3=SPC/TIP3p  W4=TIP4p (single or pairs)
#  V&F=Potential and force  V=Potential only  F=Force only
#
#  Computing:                               M-Number         M-Flops  % Flops
# -----------------------------------------------------------------------------
#  Pair Search distance check          149895.053550     1349055.482     0.1
#  NxN Ewald Elec. + LJ [F]          15268346.177040  1190931001.809    77.9
#  NxN Ewald Elec. + LJ [V&F]          154533.521872    19934824.321     1.3
#  NxN LJ [F]                         5615601.868800   252702084.096    16.5
#  NxN LJ [V&F]                         56836.490720     3694371.897     0.2
#  NxN Ewald Elec. [F]                  62783.812080     3829812.537     0.3
#  NxN Ewald Elec. [V&F]                  635.065328       53345.488     0.0
#  1,4 nonbonded interactions            2068.541370      186168.723     0.0
#  Calc Weights                         87966.109287     3166779.934     0.2
#  Spread Q Bspline                   1876610.331456     3753220.663     0.2
#  Gather F Bspline                   1876610.331456    11259661.989     0.7
#  3D-FFT                             3993844.191972    31950753.536     2.1
#  Solve PME                             1841.508864      117856.567     0.0
#  Reset In Box                           292.041642         876.125     0.0
#  CG-CoM                                 293.800929         881.403     0.0
#  Bonds                                  315.206304       18597.172     0.0
#  Propers                               2462.549250      563923.778     0.0
#  Pos. Restr.                          10182.803652      509140.183     0.0
#  Virial                               29484.039669      530712.714     0.0
#  Stop-CM                                293.800929        2938.009     0.0
#  P-Coupling                           29322.036429      175932.219     0.0
#  Calc-Ekin                            29322.622858      791710.817     0.1
#  Lincs                                  492.509850       29550.591     0.0
#  Lincs-Mat                             3309.666192       13238.665     0.0
#  Constraint-V                         19631.742627      157053.941     0.0
#  Constraint-Vir                       19139.232777      459341.587     0.0
#  Settle                                6215.574309     2007630.502     0.1
#  Urey-Bradley                          1556.331126      284808.596     0.0
# -----------------------------------------------------------------------------
#  Total                                              1528475273.343   100.0
# -----------------------------------------------------------------------------
#
#
#     D O M A I N   D E C O M P O S I T I O N   S T A T I S T I C S
#
#  av. #atoms communicated per step for force:  2 x 645965.5
#
#
# Dynamic load balancing report:
#  DLB got disabled because it was unsuitable to use.
#  Average load imbalance: 22.4%.
#  The balanceable part of the MD step is 75%, load imbalance is computed from this.
#  Part of the total run time spent waiting due to load imbalance: 16.8%.
#  Average PME mesh/force load: 0.530
#  Part of the total run time spent waiting due to PP/PME imbalance: 9.5 %
#
# NOTE: 16.8 % of the available CPU time was lost due to load imbalance
#       in the domain decomposition.
#       You might want to use dynamic load balancing (option -dlb.)
#       You can also consider manually changing the decomposition (option -dd);
#       e.g. by using fewer domains along the box dimension in which there is
#       considerable inhomogeneity in the simulated system.
# NOTE: 9.5 % performance was lost because the PME ranks
#       had less work to do than the PP ranks.
#       You might want to decrease the number of PME ranks
#       or decrease the cut-off and the grid spacing.
#
#
#      R E A L   C Y C L E   A N D   T I M E   A C C O U N T I N G
#
# On 72 MPI ranks doing PP, and
# on 24 MPI ranks doing PME
#
#  Computing:          Num   Num      Call    Wall time         Giga-Cycles
#                      Ranks Threads  Count      (s)         total sum    %
# -----------------------------------------------------------------------------
#  Domain decomp.        72    1        500       3.805        737.935   0.2
#  DD comm. load         72    1        500       0.010          1.986   0.0
#  DD comm. bounds       72    1         97       0.015          2.940   0.0
#  Send X to PME         72    1      50001       2.332        452.251   0.1
#  Neighbor search       72    1        501      11.912       2310.104   0.7
#  Comm. coord.          72    1      49500      12.974       2515.964   0.8
#  Force                 72    1      50001     638.649     123851.241  37.7
#  Wait + Comm. F        72    1      50001     222.117      43074.425  13.1
#  PME mesh *            24    1      50001     528.195      34143.720  10.4
#  PME wait for PP *                            742.427      47992.195  14.6
#  Wait + Recv. PME F    72    1      50001      30.904       5993.043   1.8
#  NB X/F buffer ops.    72    1     149001      13.059       2532.520   0.8
#  Write traj.           72    1        102       0.650        126.113   0.0
#  Update                72    1      50001       3.820        740.831   0.2
#  Constraints           72    1      50001       6.022       1167.909   0.4
#  Comm. energies        72    1      50001     310.925      60296.659  18.4
#  Rest                                          13.482       2614.566   0.8
# -----------------------------------------------------------------------------
#  Total                                       1270.677     328557.983 100.0
# -----------------------------------------------------------------------------
# (*) Note that with separate PME ranks, the walltime column actually sums to
#     twice the total reported, but the cycle count total and % are correct.
# -----------------------------------------------------------------------------
#  Breakdown of PME mesh computation
# -----------------------------------------------------------------------------
#  PME redist. X/F       24    1     100002     137.288       8874.605   2.7
#  PME spread            24    1      50001     125.902       8138.608   2.5
#  PME gather            24    1      50001      84.832       5483.767   1.7
#  PME 3D-FFT            24    1     100002      63.124       4080.483   1.2
#  PME 3D-FFT Comm.      24    1     200004      71.990       4653.618   1.4
#  PME solve Elec        24    1      50001      44.514       2877.459   0.9
# -----------------------------------------------------------------------------
#
# NOTE: 18 % of the run time was spent communicating energies,
#       you might want to use the -gcom option of mdrun
#
#                Core t (s)   Wall t (s)        (%)
#        Time:   121984.834     1270.677     9600.0
#                  (ns/day)    (hour/ns)
# Performance:        6.800        3.530
# Finished mdrun on rank 0 Tue Sep 15 05:33:25 2020
