# %% [markdown]
# # Substrate 150 Ang cube

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %config Application.log_level="DEBUG"
import logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
import os.path

# %%
from tabulate import tabulate
from pprint import pprint

# %%
from fireworks.utilities.wfb import WorkflowBuilder

# %% [markdown]
# ## NEMO

# %%
prefix= '/mnt/dat/work/testuser/adsorption/N_surfactant_on_substrate_template/fw/specific/substrate/AU/111/150Ang_cube'

# %%
wfb = WorkflowBuilder(os.path.join(prefix,'system_nemo.yaml'))
wfb.template_dir = os.path.join(prefix, 'templates')
wfb.build_dir = os.path.join(prefix, 'build_nemo')
wfb.initialize_template_engine()
try:
    undefined_variables_output = wfb.show_undefined_variables()
except Exception as e:
    print(e)
    error = e
    raise
    
### Conversion to tree with degenerate vertices
wfb.descend()
wfb.build_degenerate_graph()
#wfb.plot()
show_attributes_output = wfb.show_attributes()
## Build Workflow
try:
    wfb.fill_templates()
except Exception as e:
    print(e)
    error = e
    raise

try:
    wf = wfb.compile_workflow()
except Exception as e:
    print(e)
    error = e
    raise
# Out:
# INFO:fireworks.utilities.wfb:File '/mnt/dat/work/testuser/adsorption/N_surfactant_on_substrate_template/fw/specific/substrate/AU/111/150Ang_cube/system_nemo.yaml contains the sections ['name', 'metadata', 'std', 'transient', 'persistent', 'dependencies'].
# INFO:fireworks.utilities.wfb:Graph contains 22 nodes: ['fw_000_initial_file_retrieval.yaml', 'fw_010_datafile_retrieval.yaml', 'fw_020_minimization_fixed_box.yaml', 'fw_025_minimization_relaxed_box_file_retrieval.yaml', 'fw_030_minimization_relaxed_box.yaml', 'fw_055_equilibration_nvt_file_retrieval.yaml', 'fw_060_equilibration_nvt_bulk.yaml', 'fw_065_equilibration_npt_file_retrieval.yaml', 'fw_070_equilibration_npt_bulk.yaml', 'fw_100_extract_rdf.yaml', 'fw_110_minimization_fixed_box_extract_thermo.yaml', 'fw_120_minimization_relaxed_box_extract_thermo.yaml', 'fw_130_equilibration_nvt_extract_thermo.yaml', 'fw_140_equilibration_npt_extract_thermo.yaml', 'fw_170_minimization_fixed_box_to_filepad.yaml', 'fw_180_minimization_relaxed_box_to_filepad.yaml', 'fw_190_equilibration_nvt_to_filepad.yaml', 'fw_200_equilibration_npt_to_filepad.yaml', 'fw_220_minimization_fixed_box_to_storage.yaml', 'fw_230_minimization_relaxed_box_to_storage.yaml', 'fw_240_equilibration_nvt_to_storage.yaml', 'fw_250_equilibration_npt_to_storage.yaml'].
# INFO:fireworks.utilities.wfb:Graph contains 35 edges: [('fw_000_initial_file_retrieval.yaml', 'fw_010_datafile_retrieval.yaml'), ('fw_000_initial_file_retrieval.yaml', 'fw_020_minimization_fixed_box.yaml'), ('fw_010_datafile_retrieval.yaml', 'fw_020_minimization_fixed_box.yaml'), ('fw_010_datafile_retrieval.yaml', 'fw_025_minimization_relaxed_box_file_retrieval.yaml'), ('fw_010_datafile_retrieval.yaml', 'fw_055_equilibration_nvt_file_retrieval.yaml'), ('fw_010_datafile_retrieval.yaml', 'fw_065_equilibration_npt_file_retrieval.yaml'), ('fw_020_minimization_fixed_box.yaml', 'fw_030_minimization_relaxed_box.yaml'), ('fw_020_minimization_fixed_box.yaml', 'fw_110_minimization_fixed_box_extract_thermo.yaml'), ('fw_020_minimization_fixed_box.yaml', 'fw_170_minimization_fixed_box_to_filepad.yaml'), ('fw_020_minimization_fixed_box.yaml', 'fw_220_minimization_fixed_box_to_storage.yaml'), ('fw_110_minimization_fixed_box_extract_thermo.yaml', 'fw_170_minimization_fixed_box_to_filepad.yaml'), ('fw_110_minimization_fixed_box_extract_thermo.yaml', 'fw_220_minimization_fixed_box_to_storage.yaml'), ('fw_025_minimization_relaxed_box_file_retrieval.yaml', 'fw_030_minimization_relaxed_box.yaml'), ('fw_030_minimization_relaxed_box.yaml', 'fw_060_equilibration_nvt_bulk.yaml'), ('fw_030_minimization_relaxed_box.yaml', 'fw_120_minimization_relaxed_box_extract_thermo.yaml'), ('fw_030_minimization_relaxed_box.yaml', 'fw_180_minimization_relaxed_box_to_filepad.yaml'), ('fw_030_minimization_relaxed_box.yaml', 'fw_230_minimization_relaxed_box_to_storage.yaml'), ('fw_120_minimization_relaxed_box_extract_thermo.yaml', 'fw_180_minimization_relaxed_box_to_filepad.yaml'), ('fw_120_minimization_relaxed_box_extract_thermo.yaml', 'fw_230_minimization_relaxed_box_to_storage.yaml'), ('fw_055_equilibration_nvt_file_retrieval.yaml', 'fw_060_equilibration_nvt_bulk.yaml'), ('fw_060_equilibration_nvt_bulk.yaml', 'fw_070_equilibration_npt_bulk.yaml'), ('fw_060_equilibration_nvt_bulk.yaml', 'fw_130_equilibration_nvt_extract_thermo.yaml'), ('fw_060_equilibration_nvt_bulk.yaml', 'fw_190_equilibration_nvt_to_filepad.yaml'), ('fw_060_equilibration_nvt_bulk.yaml', 'fw_240_equilibration_nvt_to_storage.yaml'), ('fw_130_equilibration_nvt_extract_thermo.yaml', 'fw_190_equilibration_nvt_to_filepad.yaml'), ('fw_130_equilibration_nvt_extract_thermo.yaml', 'fw_240_equilibration_nvt_to_storage.yaml'), ('fw_065_equilibration_npt_file_retrieval.yaml', 'fw_070_equilibration_npt_bulk.yaml'), ('fw_070_equilibration_npt_bulk.yaml', 'fw_100_extract_rdf.yaml'), ('fw_070_equilibration_npt_bulk.yaml', 'fw_140_equilibration_npt_extract_thermo.yaml'), ('fw_070_equilibration_npt_bulk.yaml', 'fw_200_equilibration_npt_to_filepad.yaml'), ('fw_070_equilibration_npt_bulk.yaml', 'fw_250_equilibration_npt_to_storage.yaml'), ('fw_100_extract_rdf.yaml', 'fw_200_equilibration_npt_to_filepad.yaml'), ('fw_100_extract_rdf.yaml', 'fw_250_equilibration_npt_to_storage.yaml'), ('fw_140_equilibration_npt_extract_thermo.yaml', 'fw_200_equilibration_npt_to_filepad.yaml'), ('fw_140_equilibration_npt_extract_thermo.yaml', 'fw_250_equilibration_npt_to_storage.yaml')].
# INFO:fireworks.utilities.wfb:Identified root fw_000_initial_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_000_initial_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_010_datafile_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_020_minimization_fixed_box.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_025_minimization_relaxed_box_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_030_minimization_relaxed_box.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_055_equilibration_nvt_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_060_equilibration_nvt_bulk.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_065_equilibration_npt_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_070_equilibration_npt_bulk.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_100_extract_rdf.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_110_minimization_fixed_box_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_120_minimization_relaxed_box_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_130_equilibration_nvt_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_140_equilibration_npt_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_170_minimization_fixed_box_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_180_minimization_relaxed_box_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_190_equilibration_nvt_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_200_equilibration_npt_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_220_minimization_fixed_box_to_storage.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_230_minimization_relaxed_box_to_storage.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_240_equilibration_nvt_to_storage.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_250_equilibration_npt_to_storage.yaml.
# INFO:fireworks.utilities.wfb:Loading template fw_base.yaml.
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 7, 5, 3, 2, 10, 18, 14, 4, 11, 19, 15, 6, 12, 20, 16, 8, 13, 9, 21, 17]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml.
# INFO:fireworks.utilities.wfb:7: fw_065_equilibration_npt_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:5: fw_055_equilibration_nvt_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:3: fw_025_minimization_relaxed_box_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:2: fw_020_minimization_fixed_box.yaml.
# INFO:fireworks.utilities.wfb:10: fw_110_minimization_fixed_box_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:18: fw_220_minimization_fixed_box_to_storage.yaml.
# INFO:fireworks.utilities.wfb:14: fw_170_minimization_fixed_box_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:4: fw_030_minimization_relaxed_box.yaml.
# INFO:fireworks.utilities.wfb:11: fw_120_minimization_relaxed_box_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:19: fw_230_minimization_relaxed_box_to_storage.yaml.
# INFO:fireworks.utilities.wfb:15: fw_180_minimization_relaxed_box_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:6: fw_060_equilibration_nvt_bulk.yaml.
# INFO:fireworks.utilities.wfb:12: fw_130_equilibration_nvt_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:20: fw_240_equilibration_nvt_to_storage.yaml.
# INFO:fireworks.utilities.wfb:16: fw_190_equilibration_nvt_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:8: fw_070_equilibration_npt_bulk.yaml.
# INFO:fireworks.utilities.wfb:13: fw_140_equilibration_npt_extract_thermo.yaml.
# INFO:fireworks.utilities.wfb:9: fw_100_extract_rdf.yaml.
# INFO:fireworks.utilities.wfb:21: fw_250_equilibration_npt_to_storage.yaml.
# INFO:fireworks.utilities.wfb:17: fw_200_equilibration_npt_to_filepad.yaml.
# INFO:fireworks.utilities.wfb:All processed at node 17, finished.
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 7, 5, 3, 2, 10, 18, 14, 4, 11, 19, 15, 6, 12, 20, 16, 8, 13, 9, 21, 17]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml.
# INFO:fireworks.utilities.wfb:Iterating node 0: fw_000_initial_file_retrieval.yaml
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml, dist. 0, top.pos. 0 has no parents.
# INFO:fireworks.utilities.wfb:Degeneracy (persistent*transient): 1*1 = 1
# DEBUG:fireworks.utilities.wfb:  Parent name: None
# DEBUG:fireworks.utilities.wfb:  Parent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# DEBUG:fireworks.utilities.wfb:  Child persistent context updates [{}]
# DEBUG:fireworks.utilities.wfb:  Child transient context updates [{}]
# INFO:fireworks.utilities.wfb:  Iterating parent None:
# INFO:fireworks.utilities.wfb:    Iterating persitent content update 0:
# DEBUG:fireworks.utilities.wfb:      Current persistent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:      Iterating transient content update 0:
# DEBUG:fireworks.utilities.wfb:        Current transient context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:Added vertex 22 - fw_000_initial_file_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 23 - fw_010_datafile_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 24 - fw_020_minimization_fixed_box.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 25 - fw_025_minimization_relaxed_box_file_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 26 - fw_030_minimization_relaxed_box.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 27 - fw_055_equilibration_nvt_file_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 28 - fw_060_equilibration_nvt_bulk.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 29 - fw_065_equilibration_npt_file_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 30 - fw_070_equilibration_npt_bulk.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 31 - fw_100_extract_rdf.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 32 - fw_110_minimization_fixed_box_extract_thermo.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 33 - fw_120_minimization_relaxed_box_extract_thermo.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 34 - fw_130_equilibration_nvt_extract_thermo.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 35 - fw_140_equilibration_npt_extract_thermo.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 36 - fw_170_minimization_fixed_box_to_filepad.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 37 - fw_180_minimization_relaxed_box_to_filepad.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 38 - fw_190_equilibration_nvt_to_filepad.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 39 - fw_200_equilibration_npt_to_filepad.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 40 - fw_220_minimization_fixed_box_to_storage.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 41 - fw_230_minimization_relaxed_box_to_storage.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 42 - fw_240_equilibration_nvt_to_storage.yaml_000010
# INFO:fireworks.utilities.wfb:Added vertex 43 - fw_250_equilibration_npt_to_storage.yaml_000010
# INFO:fireworks.utilities.wfb:Added edge 35 - (22-23)
# INFO:fireworks.utilities.wfb:Added edge 36 - (22-24)
# INFO:fireworks.utilities.wfb:Added edge 37 - (23-24)
# INFO:fireworks.utilities.wfb:Added edge 38 - (23-25)
# INFO:fireworks.utilities.wfb:Added edge 39 - (23-27)
# INFO:fireworks.utilities.wfb:Added edge 40 - (23-29)
# INFO:fireworks.utilities.wfb:Added edge 41 - (24-26)
# INFO:fireworks.utilities.wfb:Added edge 42 - (24-32)
# INFO:fireworks.utilities.wfb:Added edge 43 - (24-36)
# INFO:fireworks.utilities.wfb:Added edge 44 - (24-40)
# INFO:fireworks.utilities.wfb:Added edge 45 - (32-36)
# INFO:fireworks.utilities.wfb:Added edge 46 - (32-40)
# INFO:fireworks.utilities.wfb:Added edge 47 - (25-26)
# INFO:fireworks.utilities.wfb:Added edge 48 - (26-28)
# INFO:fireworks.utilities.wfb:Added edge 49 - (26-33)
# INFO:fireworks.utilities.wfb:Added edge 50 - (26-37)
# INFO:fireworks.utilities.wfb:Added edge 51 - (26-41)
# INFO:fireworks.utilities.wfb:Added edge 52 - (33-37)
# INFO:fireworks.utilities.wfb:Added edge 53 - (33-41)
# INFO:fireworks.utilities.wfb:Added edge 54 - (27-28)
# INFO:fireworks.utilities.wfb:Added edge 55 - (28-30)
# INFO:fireworks.utilities.wfb:Added edge 56 - (28-34)
# INFO:fireworks.utilities.wfb:Added edge 57 - (28-38)
# INFO:fireworks.utilities.wfb:Added edge 58 - (28-42)
# INFO:fireworks.utilities.wfb:Added edge 59 - (34-38)
# INFO:fireworks.utilities.wfb:Added edge 60 - (34-42)
# INFO:fireworks.utilities.wfb:Added edge 61 - (29-30)
# INFO:fireworks.utilities.wfb:Added edge 62 - (30-31)
# INFO:fireworks.utilities.wfb:Added edge 63 - (30-35)
# INFO:fireworks.utilities.wfb:Added edge 64 - (30-39)
# INFO:fireworks.utilities.wfb:Added edge 65 - (30-43)
# INFO:fireworks.utilities.wfb:Added edge 66 - (31-39)
# INFO:fireworks.utilities.wfb:Added edge 67 - (31-43)
# INFO:fireworks.utilities.wfb:Added edge 68 - (35-39)
# INFO:fireworks.utilities.wfb:Added edge 69 - (35-43)
# INFO:fireworks.utilities.wfb:          Instance 22 - 10 - fw_000_initial_file_retrieval.yaml_000010 of class 0 - fw_000_initial_file_retrieval.yaml created.
# INFO:fireworks.utilities.wfb:      Completed transient content update 0:
# INFO:fireworks.utilities.wfb:    Completed persitent content update 0:
# INFO:fireworks.utilities.wfb:Identified root fw_000_initial_file_retrieval.yaml_000010.
# INFO:fireworks.utilities.wfb:      Modified graph at node 0, rebuilding topological order.
# INFO:fireworks.utilities.wfb:Completed node 0: fw_000_initial_file_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 7, 5, 3, 2, 10, 18, 14, 4, 11, 19, 15, 6, 12, 20, 16, 8, 13, 9, 21, 17]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml_000010 has been visited before, move on.
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml_000010.
# INFO:fireworks.utilities.wfb:Iterating node 1: fw_010_datafile_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml_000010, dist. 1, top.pos. 1 has 1 parents with distances [0]:
# INFO:fireworks.utilities.wfb:  0: fw_000_initial_file_retrieval.yaml_000010, dist. 0, top. pos. 0
# INFO:fireworks.utilities.wfb:    Maximum distance 0 at parent [0]
# INFO:fireworks.utilities.wfb:  0: fw_000_initial_file_retrieval.yaml_000010, dist. 0, top. pos. 0 selected as immediate parent
# INFO:fireworks.utilities.wfb:Degeneracy (persistent*transient): 1*1 = 1
# DEBUG:fireworks.utilities.wfb:  Parent name: fw_000_initial_file_retrieval.yaml_000010
# DEBUG:fireworks.utilities.wfb:  Parent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# DEBUG:fireworks.utilities.wfb:  Child persistent context updates [{}]
# DEBUG:fireworks.utilities.wfb:  Child transient context updates [{}]
# INFO:fireworks.utilities.wfb:  Iterating parent fw_000_initial_file_retrieval.yaml_000010:
# INFO:fireworks.utilities.wfb:    Iterating persitent content update 0:
# DEBUG:fireworks.utilities.wfb:      Current persistent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:      Iterating transient content update 0:
# DEBUG:fireworks.utilities.wfb:        Current transient context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:Added vertex 22 - fw_010_datafile_retrieval.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 23 - fw_020_minimization_fixed_box.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 24 - fw_025_minimization_relaxed_box_file_retrieval.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 25 - fw_030_minimization_relaxed_box.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 26 - fw_055_equilibration_nvt_file_retrieval.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 27 - fw_060_equilibration_nvt_bulk.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 28 - fw_065_equilibration_npt_file_retrieval.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 29 - fw_070_equilibration_npt_bulk.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 30 - fw_100_extract_rdf.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 31 - fw_110_minimization_fixed_box_extract_thermo.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 32 - fw_120_minimization_relaxed_box_extract_thermo.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 33 - fw_130_equilibration_nvt_extract_thermo.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 34 - fw_140_equilibration_npt_extract_thermo.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 35 - fw_170_minimization_fixed_box_to_filepad.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 36 - fw_180_minimization_relaxed_box_to_filepad.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 37 - fw_190_equilibration_nvt_to_filepad.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 38 - fw_200_equilibration_npt_to_filepad.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 39 - fw_220_minimization_fixed_box_to_storage.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 40 - fw_230_minimization_relaxed_box_to_storage.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 41 - fw_240_equilibration_nvt_to_storage.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added vertex 42 - fw_250_equilibration_npt_to_storage.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Added edge 35 - (0-22)
# INFO:fireworks.utilities.wfb:Added edge 36 - (0-23)
# INFO:fireworks.utilities.wfb:Added edge 37 - (22-23)
# INFO:fireworks.utilities.wfb:Added edge 38 - (22-24)
# INFO:fireworks.utilities.wfb:Added edge 39 - (22-26)
# INFO:fireworks.utilities.wfb:Added edge 40 - (22-28)
# INFO:fireworks.utilities.wfb:Added edge 41 - (23-25)
# INFO:fireworks.utilities.wfb:Added edge 42 - (23-31)
# INFO:fireworks.utilities.wfb:Added edge 43 - (23-35)
# INFO:fireworks.utilities.wfb:Added edge 44 - (23-39)
# INFO:fireworks.utilities.wfb:Added edge 45 - (31-35)
# INFO:fireworks.utilities.wfb:Added edge 46 - (31-39)
# INFO:fireworks.utilities.wfb:Added edge 47 - (24-25)
# INFO:fireworks.utilities.wfb:Added edge 48 - (25-27)
# INFO:fireworks.utilities.wfb:Added edge 49 - (25-32)
# INFO:fireworks.utilities.wfb:Added edge 50 - (25-36)
# INFO:fireworks.utilities.wfb:Added edge 51 - (25-40)
# INFO:fireworks.utilities.wfb:Added edge 52 - (32-36)
# INFO:fireworks.utilities.wfb:Added edge 53 - (32-40)
# INFO:fireworks.utilities.wfb:Added edge 54 - (26-27)
# INFO:fireworks.utilities.wfb:Added edge 55 - (27-29)
# INFO:fireworks.utilities.wfb:Added edge 56 - (27-33)
# INFO:fireworks.utilities.wfb:Added edge 57 - (27-37)
# INFO:fireworks.utilities.wfb:Added edge 58 - (27-41)
# INFO:fireworks.utilities.wfb:Added edge 59 - (33-37)
# INFO:fireworks.utilities.wfb:Added edge 60 - (33-41)
# INFO:fireworks.utilities.wfb:Added edge 61 - (28-29)
# INFO:fireworks.utilities.wfb:Added edge 62 - (29-30)
# INFO:fireworks.utilities.wfb:Added edge 63 - (29-34)
# INFO:fireworks.utilities.wfb:Added edge 64 - (29-38)
# INFO:fireworks.utilities.wfb:Added edge 65 - (29-42)
# INFO:fireworks.utilities.wfb:Added edge 66 - (30-38)
# INFO:fireworks.utilities.wfb:Added edge 67 - (30-42)
# INFO:fireworks.utilities.wfb:Added edge 68 - (34-38)
# INFO:fireworks.utilities.wfb:Added edge 69 - (34-42)
# INFO:fireworks.utilities.wfb:          Instance 22 - 20 - fw_010_datafile_retrieval.yaml_000020 of class 1 - fw_010_datafile_retrieval.yaml created.
# INFO:fireworks.utilities.wfb:      Completed transient content update 0:
# INFO:fireworks.utilities.wfb:    Completed persitent content update 0:
# INFO:fireworks.utilities.wfb:Identified root fw_000_initial_file_retrieval.yaml_000010.
# INFO:fireworks.utilities.wfb:      Modified graph at node 1, rebuilding topological order.
# INFO:fireworks.utilities.wfb:Completed node 1: fw_010_datafile_retrieval.yaml_000020
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 7, 5, 3, 2, 10, 18, 14, 4, 11, 19, 15, 6, 12, 20, 16, 8, 13, 9, 21, 17]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml_000010 has been visited before, move on.
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml_000020 has been visited before, move on.
# INFO:fireworks.utilities.wfb:7: fw_065_equilibration_npt_file_retrieval.yaml_000010_000020.
# INFO:fireworks.utilities.wfb:Iterating node 7: fw_065_equilibration_npt_file_retrieval.yaml_000010_000020
# INFO:fireworks.utilities.wfb:7: fw_065_equilibration_npt_file_retrieval.yaml_000010_000020, dist. 2, top.pos. 18 has 1 parents with distances [1]:
# INFO:fireworks.utilities.wfb:  1: fw_010_datafile_retrieval.yaml_000020, dist. 1, top. pos. 1
# INFO:fireworks.utilities.wfb:    Maximum distance 1 at parent [1]
# INFO:fireworks.utilities.wfb:  1: fw_010_datafile_retrieval.yaml_000020, dist. 1, top. pos. 1 selected as immediate parent
# INFO:fireworks.utilities.wfb:Degeneracy (persistent*transient): 1*1 = 1
# DEBUG:fireworks.utilities.wfb:  Parent name: fw_010_datafile_retrieval.yaml_000020
# DEBUG:fireworks.utilities.wfb:  Parent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# DEBUG:fireworks.utilities.wfb:  Child persistent context updates [{}]
# DEBUG:fireworks.utilities.wfb:  Child transient context updates [{}]
# INFO:fireworks.utilities.wfb:  Iterating parent fw_010_datafile_retrieval.yaml_000020:
# INFO:fireworks.utilities.wfb:    Iterating persitent content update 0:
# DEBUG:fireworks.utilities.wfb:      Current persistent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:      Iterating transient content update 0:
# DEBUG:fireworks.utilities.wfb:        Current transient context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:Added vertex 22 - fw_065_equilibration_npt_file_retrieval.yaml_000010_000020_000030
# INFO:fireworks.utilities.wfb:Added vertex 23 - fw_070_equilibration_npt_bulk.yaml_000010_000020_000030
# INFO:fireworks.utilities.wfb:Added vertex 24 - fw_100_extract_rdf.yaml_000010_000020_000030
# INFO:fireworks.utilities.wfb:Added vertex 25 - fw_140_equilibration_npt_extract_thermo.yaml_000010_000020_000030
# INFO:fireworks.utilities.wfb:Added vertex 26 - fw_200_equilibration_npt_to_filepad.yaml_000010_000020_000030
# INFO:fireworks.utilities.wfb:Added vertex 27 - fw_250_equilibration_npt_to_storage.yaml_000010_000020_000030
# INFO:fireworks.utilities.wfb:Added edge 35 - (24-27)
# INFO:fireworks.utilities.wfb:Added edge 36 - (25-26)
# INFO:fireworks.utilities.wfb:Added edge 37 - (25-27)
# INFO:fireworks.utilities.wfb:Added edge 38 - (1-22)
# INFO:fireworks.utilities.wfb:Added edge 39 - (6-23)
# INFO:fireworks.utilities.wfb:Added edge 40 - (22-23)
# INFO:fireworks.utilities.wfb:Added edge 41 - (23-24)
# INFO:fireworks.utilities.wfb:Added edge 42 - (23-25)
# INFO:fireworks.utilities.wfb:Added edge 43 - (23-26)
# INFO:fireworks.utilities.wfb:Added edge 44 - (23-27)
# INFO:fireworks.utilities.wfb:Added edge 45 - (24-26)
# INFO:fireworks.utilities.wfb:          Instance 22 - 30 - fw_065_equilibration_npt_file_retrieval.yaml_000030 of class 7 - fw_065_equilibration_npt_file_retrieval.yaml created.
# INFO:fireworks.utilities.wfb:      Completed transient content update 0:
# INFO:fireworks.utilities.wfb:    Completed persitent content update 0:
# INFO:fireworks.utilities.wfb:Identified root fw_000_initial_file_retrieval.yaml_000010.
# INFO:fireworks.utilities.wfb:      Modified graph at node 7, rebuilding topological order.
# INFO:fireworks.utilities.wfb:Completed node 7: fw_110_minimization_fixed_box_extract_thermo.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 16, 5, 3, 2, 7, 13, 10, 4, 8, 14, 11, 6, 17, 19, 18, 21, 20, 9, 15, 12]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml_000010 has been visited before, move on.
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml_000020 has been visited before, move on.
# INFO:fireworks.utilities.wfb:16: fw_065_equilibration_npt_file_retrieval.yaml_000030 has been visited before, move on.
# INFO:fireworks.utilities.wfb:5: fw_055_equilibration_nvt_file_retrieval.yaml_000010_000020.
# INFO:fireworks.utilities.wfb:Iterating node 5: fw_055_equilibration_nvt_file_retrieval.yaml_000010_000020
# INFO:fireworks.utilities.wfb:5: fw_055_equilibration_nvt_file_retrieval.yaml_000010_000020, dist. 2, top.pos. 2 has 1 parents with distances [1]:
# INFO:fireworks.utilities.wfb:  1: fw_010_datafile_retrieval.yaml_000020, dist. 1, top. pos. 1
# INFO:fireworks.utilities.wfb:    Maximum distance 1 at parent [1]
# INFO:fireworks.utilities.wfb:  1: fw_010_datafile_retrieval.yaml_000020, dist. 1, top. pos. 1 selected as immediate parent
# INFO:fireworks.utilities.wfb:Degeneracy (persistent*transient): 1*1 = 1
# DEBUG:fireworks.utilities.wfb:  Parent name: fw_010_datafile_retrieval.yaml_000020
# DEBUG:fireworks.utilities.wfb:  Parent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# DEBUG:fireworks.utilities.wfb:  Child persistent context updates [{}]
# DEBUG:fireworks.utilities.wfb:  Child transient context updates [{}]
# INFO:fireworks.utilities.wfb:  Iterating parent fw_010_datafile_retrieval.yaml_000020:
# INFO:fireworks.utilities.wfb:    Iterating persitent content update 0:
# DEBUG:fireworks.utilities.wfb:      Current persistent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:      Iterating transient content update 0:
# DEBUG:fireworks.utilities.wfb:        Current transient context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K'}
# INFO:fireworks.utilities.wfb:Added vertex 22 - fw_055_equilibration_nvt_file_retrieval.yaml_000010_000020_000040
# INFO:fireworks.utilities.wfb:Added vertex 23 - fw_060_equilibration_nvt_bulk.yaml_000010_000020_000040
# INFO:fireworks.utilities.wfb:Added vertex 24 - fw_130_equilibration_nvt_extract_thermo.yaml_000010_000020_000040
# INFO:fireworks.utilities.wfb:Added vertex 25 - fw_190_equilibration_nvt_to_filepad.yaml_000010_000020_000040
# INFO:fireworks.utilities.wfb:Added vertex 26 - fw_240_equilibration_nvt_to_storage.yaml_000010_000020_000040
# INFO:fireworks.utilities.wfb:Added vertex 27 - fw_070_equilibration_npt_bulk.yaml_000010_000020_000030_000040
# INFO:fireworks.utilities.wfb:Added vertex 28 - fw_100_extract_rdf.yaml_000010_000020_000030_000040
# INFO:fireworks.utilities.wfb:Added vertex 29 - fw_140_equilibration_npt_extract_thermo.yaml_000010_000020_000030_000040
# INFO:fireworks.utilities.wfb:Added vertex 30 - fw_200_equilibration_npt_to_filepad.yaml_000010_000020_000030_000040
# INFO:fireworks.utilities.wfb:Added vertex 31 - fw_250_equilibration_npt_to_storage.yaml_000010_000020_000030_000040
# INFO:fireworks.utilities.wfb:Added edge 35 - (27-30)
# INFO:fireworks.utilities.wfb:Added edge 36 - (27-31)
# INFO:fireworks.utilities.wfb:Added edge 37 - (28-30)
# INFO:fireworks.utilities.wfb:Added edge 38 - (1-22)
# INFO:fireworks.utilities.wfb:Added edge 39 - (4-23)
# INFO:fireworks.utilities.wfb:Added edge 40 - (22-23)
# INFO:fireworks.utilities.wfb:Added edge 41 - (23-24)
# INFO:fireworks.utilities.wfb:Added edge 42 - (23-25)
# INFO:fireworks.utilities.wfb:Added edge 43 - (23-26)
# INFO:fireworks.utilities.wfb:Added edge 44 - (24-25)
# INFO:fireworks.utilities.wfb:Added edge 45 - (24-26)
# INFO:fireworks.utilities.wfb:Added edge 46 - (28-31)
# INFO:fireworks.utilities.wfb:Added edge 47 - (29-30)
# INFO:fireworks.utilities.wfb:Added edge 48 - (29-31)
# INFO:fireworks.utilities.wfb:Added edge 49 - (23-27)
# INFO:fireworks.utilities.wfb:Added edge 50 - (16-27)
# INFO:fireworks.utilities.wfb:Added edge 51 - (27-28)
# INFO:fireworks.utilities.wfb:Added edge 52 - (27-29)
# INFO:fireworks.utilities.wfb:          Instance 22 - 40 - fw_055_equilibration_nvt_file_retrieval.yaml_000040 of class 5 - fw_055_equilibration_nvt_file_retrieval.yaml created.
# INFO:fireworks.utilities.wfb:      Completed transient content update 0:
# INFO:fireworks.utilities.wfb:    Completed persitent content update 0:
# INFO:fireworks.utilities.wfb:Identified root fw_000_initial_file_retrieval.yaml_000010.
# INFO:fireworks.utilities.wfb:      Modified graph at node 5, rebuilding topological order.
# INFO:fireworks.utilities.wfb:Completed node 5: fw_110_minimization_fixed_box_extract_thermo.yaml_000010_000020
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 12, 11, 3, 2, 5, 9, 7, 4, 13, 17, 19, 18, 21, 20, 14, 16, 15, 6, 10, 8]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml_000010 has been visited before, move on.
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml_000020 has been visited before, move on.
# INFO:fireworks.utilities.wfb:12: fw_055_equilibration_nvt_file_retrieval.yaml_000040 has been visited before, move on.
# INFO:fireworks.utilities.wfb:11: fw_065_equilibration_npt_file_retrieval.yaml_000030 has been visited before, move on.
# INFO:fireworks.utilities.wfb:3: fw_025_minimization_relaxed_box_file_retrieval.yaml_000010_000020.
# INFO:fireworks.utilities.wfb:Iterating node 3: fw_025_minimization_relaxed_box_file_retrieval.yaml_000010_000020
# ...
# INFO:fireworks.utilities.wfb:20: fw_200_equilibration_npt_to_filepad.yaml_000010_000020_000030_000040_000050_000060_000100_000140_000180_000190_000200.
# INFO:fireworks.utilities.wfb:Iterating node 20: fw_200_equilibration_npt_to_filepad.yaml_000010_000020_000030_000040_000050_000060_000100_000140_000180_000190_000200
# INFO:fireworks.utilities.wfb:20: fw_200_equilibration_npt_to_filepad.yaml_000010_000020_000030_000040_000050_000060_000100_000140_000180_000190_000200, dist. 7, top.pos. 21 has 3 parents with distances [5, 6, 6]:
# INFO:fireworks.utilities.wfb:  17: fw_070_equilibration_npt_bulk.yaml_000180, dist. 5, top. pos. 17
# INFO:fireworks.utilities.wfb:  18: fw_140_equilibration_npt_extract_thermo.yaml_000190, dist. 6, top. pos. 19
# INFO:fireworks.utilities.wfb:  19: fw_100_extract_rdf.yaml_000200, dist. 6, top. pos. 18
# INFO:fireworks.utilities.wfb:    Maximum distance 6 at parent [18, 19]
# WARNING:fireworks.utilities.wfb:  2 parents are equally closest to child: Choice of context not unique.
# WARNING:fireworks.utilities.wfb:    18: fw_140_equilibration_npt_extract_thermo.yaml_000190, dist. 6, top. pos. 19
# WARNING:fireworks.utilities.wfb:    19: fw_100_extract_rdf.yaml_000200, dist. 6, top. pos. 18
# WARNING:fireworks.utilities.wfb:  Choice of context not unique.
# INFO:fireworks.utilities.wfb:  18: fw_140_equilibration_npt_extract_thermo.yaml_000190, dist. 6, top. pos. 19 selected as immediate parent
# INFO:fireworks.utilities.wfb:Degeneracy (persistent*transient): 1*1 = 1
# DEBUG:fireworks.utilities.wfb:  Parent name: fw_140_equilibration_npt_extract_thermo.yaml_000190
# DEBUG:fireworks.utilities.wfb:  Parent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K', 'step': 'equilibration_npt'}
# DEBUG:fireworks.utilities.wfb:  Child persistent context updates [{}]
# DEBUG:fireworks.utilities.wfb:  Child transient context updates [{}]
# INFO:fireworks.utilities.wfb:  Iterating parent fw_140_equilibration_npt_extract_thermo.yaml_000190:
# INFO:fireworks.utilities.wfb:    Iterating persitent content update 0:
# DEBUG:fireworks.utilities.wfb:      Current persistent context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K', 'step': 'equilibration_npt'}
# INFO:fireworks.utilities.wfb:      Iterating transient content update 0:
# DEBUG:fireworks.utilities.wfb:        Current transient context: {'machine': 'NEMO', 'nodes': 2, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'worker': 'nemo_noqueue', 'smb_gateway': '132.230.102.164', 'smb_gateway_user': 'sshclient', 'smb_gateway_ssh_id': '~/.ssh/sshclient-frrzvm', 'smb_host': 'ufr2.isi1.public.ads.uni-freiburg.de', 'smb_port': 445, 'coeff_identifier': 'SDS/in/H2O/on/AU/coeff/hybrid/lj/charmmfsw/coul/charmmfsh/nonbonded.input', 'ewald_accuracy': 0.0001, 'coulomb_cutoff': 8.0, 'coulomb_cutoff_unit': 'Ang', 'skin_distance': 3.0, 'skin_distance_unit': 'Ang', 'mpiio': 1, 'neigh_delay': 2, 'neigh_every': 1, 'neigh_check': 1, 'netcdf_frequency': 100, 'thermo_frequency': 100, 'thermo_average_frequency': 100, 'minimization_ftol': 1e-06, 'minimization_ftol_unit': 'kcal', 'minimization_maxiter': 10000, 'minimization_maxeval': 100000, 'nvt_equilibration_steps': 10000, 'npt_equilibration_steps': 10000, 'use_barostat': 0, 'use_berenden_bstat': 0, 'use_dpd_tstat': 0, 'use_eam': 0, 'use_ewald': 1, 'system_name': 'AU_111_150Ang_cube', 'state': 'initial config', 'pbc': 111, 'pressure': 1, 'pressure_unit': 'atm', 'sb_name': 'AU_111_150Ang_cube', 'sb_area': 2.25e-16, 'sb_area_unit': 'm^2', 'sb_base_length': 150, 'sb_base_length_unit': 'Ang', 'sb_crystal_plane': 111, 'sb_lattice_constant': 4.075, 'sb_lattice_constant_unit': 'Ang', 'sb_measures': [1.50412e-08, 1.49725e-08, 1.50338e-08], 'sb_measures_unit': 'm', 'sb_natoms': 201600, 'sb_normal': 2, 'sb_shape': 'cube', 'sb_thickness': 1.5e-08, 'sb_thickness_unit': 'm', 'sb_volume': 3.375e-23, 'sb_volume_unit': 'm^3', 'substrate': 'AU', 'temperature': 298, 'temperature_unit': 'K', 'step': 'equilibration_npt'}
# INFO:fireworks.utilities.wfb:Added vertex 22 - fw_200_equilibration_npt_to_filepad.yaml_000010_000020_000030_000040_000050_000060_000100_000140_000180_000190_000200_000220
# INFO:fireworks.utilities.wfb:Added edge 35 - (18-22)
# INFO:fireworks.utilities.wfb:Added edge 36 - (17-22)
# INFO:fireworks.utilities.wfb:Added edge 37 - (19-22)
# INFO:fireworks.utilities.wfb:          Instance 22 - 220 - fw_200_equilibration_npt_to_filepad.yaml_000220 of class 20 - fw_200_equilibration_npt_to_filepad.yaml created.
# INFO:fireworks.utilities.wfb:      Completed transient content update 0:
# INFO:fireworks.utilities.wfb:    Completed persitent content update 0:
# INFO:fireworks.utilities.wfb:Identified root fw_000_initial_file_retrieval.yaml_000010.
# INFO:fireworks.utilities.wfb:      Modified graph at node 20, rebuilding topological order.
# INFO:fireworks.utilities.wfb:Completed node 20: fw_250_equilibration_npt_to_storage.yaml_000210
# INFO:fireworks.utilities.wfb:Current topological order: [0, 1, 5, 6, 8, 7, 4, 9, 10, 12, 11, 3, 13, 14, 16, 15, 2, 17, 19, 18, 21, 20]
# INFO:fireworks.utilities.wfb:0: fw_000_initial_file_retrieval.yaml_000010 has been visited before, move on.
# INFO:fireworks.utilities.wfb:1: fw_010_datafile_retrieval.yaml_000020 has been visited before, move on.
# INFO:fireworks.utilities.wfb:5: fw_020_minimization_fixed_box.yaml_000060 has been visited before, move on.
# INFO:fireworks.utilities.wfb:6: fw_110_minimization_fixed_box_extract_thermo.yaml_000070 has been visited before, move on.
# INFO:fireworks.utilities.wfb:8: fw_220_minimization_fixed_box_to_storage.yaml_000090 has been visited before, move on.
# INFO:fireworks.utilities.wfb:7: fw_170_minimization_fixed_box_to_filepad.yaml_000080 has been visited before, move on.
# INFO:fireworks.utilities.wfb:4: fw_025_minimization_relaxed_box_file_retrieval.yaml_000050 has been visited before, move on.
# INFO:fireworks.utilities.wfb:9: fw_030_minimization_relaxed_box.yaml_000100 has been visited before, move on.
# INFO:fireworks.utilities.wfb:10: fw_120_minimization_relaxed_box_extract_thermo.yaml_000110 has been visited before, move on.
# INFO:fireworks.utilities.wfb:12: fw_180_minimization_relaxed_box_to_filepad.yaml_000130 has been visited before, move on.
# INFO:fireworks.utilities.wfb:11: fw_230_minimization_relaxed_box_to_storage.yaml_000120 has been visited before, move on.
# INFO:fireworks.utilities.wfb:3: fw_055_equilibration_nvt_file_retrieval.yaml_000040 has been visited before, move on.
# INFO:fireworks.utilities.wfb:13: fw_060_equilibration_nvt_bulk.yaml_000140 has been visited before, move on.
# INFO:fireworks.utilities.wfb:14: fw_130_equilibration_nvt_extract_thermo.yaml_000150 has been visited before, move on.
# INFO:fireworks.utilities.wfb:16: fw_240_equilibration_nvt_to_storage.yaml_000170 has been visited before, move on.
# INFO:fireworks.utilities.wfb:15: fw_190_equilibration_nvt_to_filepad.yaml_000160 has been visited before, move on.
# INFO:fireworks.utilities.wfb:2: fw_065_equilibration_npt_file_retrieval.yaml_000030 has been visited before, move on.
# INFO:fireworks.utilities.wfb:17: fw_070_equilibration_npt_bulk.yaml_000180 has been visited before, move on.
# INFO:fireworks.utilities.wfb:19: fw_100_extract_rdf.yaml_000200 has been visited before, move on.
# INFO:fireworks.utilities.wfb:18: fw_140_equilibration_npt_extract_thermo.yaml_000190 has been visited before, move on.
# INFO:fireworks.utilities.wfb:21: fw_200_equilibration_npt_to_filepad.yaml_000220 has been visited before, move on.
# INFO:fireworks.utilities.wfb:20: fw_250_equilibration_npt_to_storage.yaml_000210 has been visited before, move on.
# INFO:fireworks.utilities.wfb:All processed at node 20, finished.
# INFO:fireworks.utilities.wfb:Set of Fireworks:['fw_000_initial_file_retrieval.yaml_000010', 'fw_010_datafile_retrieval.yaml_000020', 'fw_020_minimization_fixed_box.yaml_000060', 'fw_025_minimization_relaxed_box_file_retrieval.yaml_000050', 'fw_030_minimization_relaxed_box.yaml_000100', 'fw_055_equilibration_nvt_file_retrieval.yaml_000040', 'fw_060_equilibration_nvt_bulk.yaml_000140', 'fw_065_equilibration_npt_file_retrieval.yaml_000030', 'fw_070_equilibration_npt_bulk.yaml_000180', 'fw_100_extract_rdf.yaml_000200', 'fw_110_minimization_fixed_box_extract_thermo.yaml_000070', 'fw_120_minimization_relaxed_box_extract_thermo.yaml_000110', 'fw_130_equilibration_nvt_extract_thermo.yaml_000150', 'fw_140_equilibration_npt_extract_thermo.yaml_000190', 'fw_170_minimization_fixed_box_to_filepad.yaml_000080', 'fw_180_minimization_relaxed_box_to_filepad.yaml_000130', 'fw_190_equilibration_nvt_to_filepad.yaml_000160', 'fw_200_equilibration_npt_to_filepad.yaml_000220', 'fw_220_minimization_fixed_box_to_storage.yaml_000090', 'fw_230_minimization_relaxed_box_to_storage.yaml_000120', 'fw_240_equilibration_nvt_to_storage.yaml_000170', 'fw_250_equilibration_npt_to_storage.yaml_000210'].
# INFO:fireworks.utilities.wfb:Loading files 'fw_000_initial_file_retrieval.yaml_000010'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_010_datafile_retrieval.yaml_000020'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_020_minimization_fixed_box.yaml_000060'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_025_minimization_relaxed_box_file_retrieval.yaml_000050'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_030_minimization_relaxed_box.yaml_000100'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_055_equilibration_nvt_file_retrieval.yaml_000040'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_060_equilibration_nvt_bulk.yaml_000140'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_065_equilibration_npt_file_retrieval.yaml_000030'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_070_equilibration_npt_bulk.yaml_000180'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_100_extract_rdf.yaml_000200'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_110_minimization_fixed_box_extract_thermo.yaml_000070'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_120_minimization_relaxed_box_extract_thermo.yaml_000110'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_130_equilibration_nvt_extract_thermo.yaml_000150'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_140_equilibration_npt_extract_thermo.yaml_000190'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_170_minimization_fixed_box_to_filepad.yaml_000080'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_180_minimization_relaxed_box_to_filepad.yaml_000130'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_190_equilibration_nvt_to_filepad.yaml_000160'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_200_equilibration_npt_to_filepad.yaml_000220'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_220_minimization_fixed_box_to_storage.yaml_000090'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_230_minimization_relaxed_box_to_storage.yaml_000120'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_240_equilibration_nvt_to_storage.yaml_000170'.
# INFO:fireworks.utilities.wfb:Loading files 'fw_250_equilibration_npt_to_storage.yaml_000210'.
# INFO:fireworks.utilities.wfb:fw_id  -10: fw_000_initial_file_retrieval.yaml_000010
# INFO:fireworks.utilities.wfb:fw_id  -20: fw_010_datafile_retrieval.yaml_000020
# INFO:fireworks.utilities.wfb:fw_id  -30: fw_020_minimization_fixed_box.yaml_000060
# INFO:fireworks.utilities.wfb:fw_id  -40: fw_025_minimization_relaxed_box_file_retrieval.yaml_000050
# INFO:fireworks.utilities.wfb:fw_id  -50: fw_030_minimization_relaxed_box.yaml_000100
# INFO:fireworks.utilities.wfb:fw_id  -60: fw_055_equilibration_nvt_file_retrieval.yaml_000040
# INFO:fireworks.utilities.wfb:fw_id  -70: fw_060_equilibration_nvt_bulk.yaml_000140
# INFO:fireworks.utilities.wfb:fw_id  -80: fw_065_equilibration_npt_file_retrieval.yaml_000030
# INFO:fireworks.utilities.wfb:fw_id  -90: fw_070_equilibration_npt_bulk.yaml_000180
# INFO:fireworks.utilities.wfb:fw_id -100: fw_100_extract_rdf.yaml_000200
# INFO:fireworks.utilities.wfb:fw_id -110: fw_110_minimization_fixed_box_extract_thermo.yaml_000070
# INFO:fireworks.utilities.wfb:fw_id -120: fw_120_minimization_relaxed_box_extract_thermo.yaml_000110
# INFO:fireworks.utilities.wfb:fw_id -130: fw_130_equilibration_nvt_extract_thermo.yaml_000150
# INFO:fireworks.utilities.wfb:fw_id -140: fw_140_equilibration_npt_extract_thermo.yaml_000190
# INFO:fireworks.utilities.wfb:fw_id -150: fw_170_minimization_fixed_box_to_filepad.yaml_000080
# INFO:fireworks.utilities.wfb:fw_id -160: fw_180_minimization_relaxed_box_to_filepad.yaml_000130
# INFO:fireworks.utilities.wfb:fw_id -170: fw_190_equilibration_nvt_to_filepad.yaml_000160
# INFO:fireworks.utilities.wfb:fw_id -180: fw_200_equilibration_npt_to_filepad.yaml_000220
# INFO:fireworks.utilities.wfb:fw_id -190: fw_220_minimization_fixed_box_to_storage.yaml_000090
# INFO:fireworks.utilities.wfb:fw_id -200: fw_230_minimization_relaxed_box_to_storage.yaml_000120
# INFO:fireworks.utilities.wfb:fw_id -210: fw_240_equilibration_nvt_to_storage.yaml_000170
# INFO:fireworks.utilities.wfb:fw_id -220: fw_250_equilibration_npt_to_storage.yaml_000210

# %%
wfb.plot()
