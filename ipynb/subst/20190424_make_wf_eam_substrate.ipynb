# %% [markdown]
# # Build Workflow

# %%
# %load_ext autoreload
# %autoreload 2
# %config Application.log_level="DEBUG"

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
import os.path

# %%
from tabulate import tabulate
from pprint import pprint

# %%
from fireworks.utilities.wfb import WorkflowBuilder

# %% [markdown]
# # Build workflow from templates

# %%
prefix = '/mnt/dat/work/testuser/adsorption/N_surfactant_on_substrate_template/fw/specific/substrate/AU/111/51x30x21'
wfb = WorkflowBuilder(os.path.join(prefix,'system.yaml'))
wfb.template_dir = os.path.join(prefix, 'templates')
wfb.build_dir = os.path.join(prefix, 'build')
wfb.initialize_template_engine()
print(wfb.show_undefined_variables())
### Conversion to tree with degenerate vertices
wfb.descend()
wfb.build_degenerate_graph()
wfb.plot()
print(wfb.show_attributes())
## Build Workflow
wfb.fill_templates()
wf = wfb.compile_workflow()
# Out:
# ╒═══════════════════════════════════════════╤══════════════╤═══════════════╤════════════╤═════╤══════════╤═══════════╤═════════╤═══════════╤══════════════════╤══════════════════╤═════════╤════════╤═══════╤═══════╤═════════╤══════════════════╤════════════╤══════════════════════╤══════════╤═════════════╤═════════════╕
# │                                           │ sb_multiples │ pressure_unit │ surfactant │ ppn │ walltime │ remote_ip │ ssh_key │ substrate │ temperature_unit │ coeff_identifier │ sb_name │ worker │ queue │ nodes │ machine │ sb_crystal_plane │ remote_dir │ substrate_identifier │ pressure │ temperature │ remote_user │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_010_file_retrieval.yaml                │              │               │            │     │          │           │         │           │                  │ x                │         │ x      │       │       │ x       │                  │            │ x                    │          │             │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_020_minimization_fixed_box.yaml        │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │          │             │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_030_minimization_relaxed_box.yaml      │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │ x        │             │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_040_minimization_slab_fixed_box.yaml   │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │          │             │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_050_minimization_slab_relaxed_box.yaml │              │               │            │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │ x        │             │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_060_equilibration_nvt_bulk.yaml        │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │          │ x           │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_070_equilibration_npt_bulk.yaml        │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │ x        │ x           │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_080_equilibration_nvt_slab.yaml        │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │          │ x           │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_090_equilibration_npt_slab.yaml        │              │               │ x          │ x   │ x        │           │         │           │                  │                  │         │ x      │ x     │ x     │ x       │                  │            │                      │ x        │ x           │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_100_extract_property.yaml              │              │               │            │     │          │           │         │           │                  │                  │         │ x      │       │       │ x       │                  │            │                      │          │             │             │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_150_remote_file_transfer.yaml          │ x            │               │            │     │          │ x         │ x       │ x         │                  │                  │         │ x      │       │       │         │ x                │ x          │                      │          │             │ x           │
# ├───────────────────────────────────────────┼──────────────┼───────────────┼────────────┼─────┼──────────┼───────────┼─────────┼───────────┼──────────────────┼──────────────────┼─────────┼────────┼───────┼───────┼─────────┼──────────────────┼────────────┼──────────────────────┼──────────┼─────────────┼─────────────┤
# │ fw_200_filepad_add.yaml                   │ x            │ x             │            │     │          │           │         │ x         │ x                │                  │ x       │ x      │       │       │ x       │ x                │            │                      │ x        │ x           │             │
# ╘═══════════════════════════════════════════╧══════════════╧═══════════════╧════════════╧═════╧══════════╧═══════════╧═════════╧═══════════╧══════════════════╧══════════════════╧═════════╧════════╧═══════╧═══════╧═════════╧══════════════════╧════════════╧══════════════════════╧══════════╧═════════════╧═════════════╛
# -  -------------------------------------------  ------------------------------------  -----  ----  ----------  -----
#    name                                         template                              order  dist  degeneracy  fw_id
# 0  fw_010_file_retrieval.yaml_000010            fw_010_file_retrieval.yaml            0      0     1           10
# 1  fw_020_minimization_fixed_box.yaml_000020    fw_020_minimization_fixed_box.yaml    1      1     1           20
# 2  fw_030_minimization_relaxed_box.yaml_000030  fw_030_minimization_relaxed_box.yaml  2      2     1           30
# 3  fw_060_equilibration_nvt_bulk.yaml_000040    fw_060_equilibration_nvt_bulk.yaml    3      3     1           40
# 4  fw_070_equilibration_npt_bulk.yaml_000050    fw_070_equilibration_npt_bulk.yaml    4      4     1           50
# 5  fw_200_filepad_add.yaml_000060               fw_200_filepad_add.yaml               6      5     1           60
# 6  fw_100_extract_property.yaml_000070          fw_100_extract_property.yaml          7      5     1           70
# 7  fw_150_remote_file_transfer.yaml_000080      fw_150_remote_file_transfer.yaml      5      6     1           80
# -  -------------------------------------------  ------------------------------------  -----  ----  ----------  -----

# %%
wfb.plot()

# %%
wfb.initialize_template_engine()

# %%
h = wfb.build_degenerate_graph()

# %%
wfb.plot(wfb.h)

# %%
print(wfb.show_attributes())
# Out:
# -  -------------------------------------------  ------------------------------------  -----  ----  ----------  -----
#    name                                         template                              order  dist  degeneracy  fw_id
# 0  fw_010_file_retrieval.yaml_000010            fw_010_file_retrieval.yaml            0      0     1           10
# 1  fw_020_minimization_fixed_box.yaml_000020    fw_020_minimization_fixed_box.yaml    1      1     1           20
# 2  fw_030_minimization_relaxed_box.yaml_000030  fw_030_minimization_relaxed_box.yaml  2      2     1           30
# 3  fw_060_equilibration_nvt_bulk.yaml_000040    fw_060_equilibration_nvt_bulk.yaml    3      3     1           40
# 4  fw_070_equilibration_npt_bulk.yaml_000050    fw_070_equilibration_npt_bulk.yaml    4      4     1           50
# 5  fw_200_filepad_add.yaml_000060               fw_200_filepad_add.yaml               6      5     1           60
# 6  fw_100_extract_property.yaml_000070          fw_100_extract_property.yaml          7      5     1           70
# 7  fw_150_remote_file_transfer.yaml_000080      fw_150_remote_file_transfer.yaml      5      6     1           80
# -  -------------------------------------------  ------------------------------------  -----  ----  ----------  -----

# %% [markdown]
# ## Build Workflow

# %%
wfb.g.vs[0]["transient"]
# Out:
# {'machine': 'NEMO',
#  'nodes': 1,
#  'ppn': 20,
#  'pressure': 0,
#  'queue': 'express',
#  'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8',
#  'remote_user': 'testuser',
#  'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud',
#  'substrate_identifier': 'substrate/AU/111/52x30x8.lammps',
#  'surfactant': 'SDS',
#  'temperature': 298,
#  'walltime': '00:15:00',
#  'worker': 'nemo_noqueue'}

# %%
wfb.fill_templates()

# %%
wfb.compile_workflow()
# Out:
# [INFO - wfb.py:152 - compile_workflow() ] Set of Fireworks:{'fw_150_remote_file_transfer.yaml_000170', 'fw_150_remote_file_transfer.yaml_000080', 'fw_020_minimization_fixed_box.yaml_000020', 'fw_100_extract_property.yaml_000180', 'fw_080_equilibration_nvt_slab.yaml_000130', 'fw_100_extract_property.yaml_000090', 'fw_030_minimization_relaxed_box.yaml_000030', 'fw_060_equilibration_nvt_bulk.yaml_000040', 'fw_070_equilibration_npt_bulk.yaml_000060', 'fw_090_equilibration_npt_slab.yaml_000140', 'fw_090_equilibration_npt_slab.yaml_000150', 'fw_050_minimization_slab_relaxed_box.yaml_000120', 'fw_100_extract_property.yaml_000070', 'fw_100_extract_property.yaml_000160', 'fw_150_remote_file_transfer.yaml_000100', 'fw_070_equilibration_npt_bulk.yaml_000050', 'fw_150_remote_file_transfer.yaml_000190', 'fw_010_file_retrieval.yaml_000010', 'fw_040_minimization_slab_fixed_box.yaml_000110'}. (2019-04-11 16:24:04,027)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_150_remote_file_transfer.yaml_000170'. (2019-04-11 16:24:04,028)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_150_remote_file_transfer.yaml_000080'. (2019-04-11 16:24:04,059)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_020_minimization_fixed_box.yaml_000020'. (2019-04-11 16:24:04,072)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_100_extract_property.yaml_000180'. (2019-04-11 16:24:04,103)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_080_equilibration_nvt_slab.yaml_000130'. (2019-04-11 16:24:04,120)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_100_extract_property.yaml_000090'. (2019-04-11 16:24:04,136)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_030_minimization_relaxed_box.yaml_000030'. (2019-04-11 16:24:04,151)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_060_equilibration_nvt_bulk.yaml_000040'. (2019-04-11 16:24:04,164)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_070_equilibration_npt_bulk.yaml_000060'. (2019-04-11 16:24:04,178)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_090_equilibration_npt_slab.yaml_000140'. (2019-04-11 16:24:04,192)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_090_equilibration_npt_slab.yaml_000150'. (2019-04-11 16:24:04,206)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_050_minimization_slab_relaxed_box.yaml_000120'. (2019-04-11 16:24:04,220)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_100_extract_property.yaml_000070'. (2019-04-11 16:24:04,233)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_100_extract_property.yaml_000160'. (2019-04-11 16:24:04,246)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_150_remote_file_transfer.yaml_000100'. (2019-04-11 16:24:04,260)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_070_equilibration_npt_bulk.yaml_000050'. (2019-04-11 16:24:04,267)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_150_remote_file_transfer.yaml_000190'. (2019-04-11 16:24:04,281)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_010_file_retrieval.yaml_000010'. (2019-04-11 16:24:04,288)
# [INFO - wfb.py:157 - compile_workflow() ] Loading files 'fw_040_minimization_slab_fixed_box.yaml_000110'. (2019-04-11 16:24:04,307)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2070-096d393068ef> in <module>()
# ----> 1 wfb.compile_workflow()
#
# /opt/apps/fireworks/1.8.7/venv/fireworks-python-3.6/lib/python3.6/site-packages/fireworks/utilities/wfb.py in compile_workflow(self, outfile, from_files)
#     161         for name, fw in fws_dict.items():
#     162             fw.fw_id = fws_id[name]
# --> 163             self.logger.info("{: 4d}: {:s}".format(fw_id, name))
#     164
#     165         fws_list = list(fws_dict.values())
#
# NameError: name 'fw_id' is not defined

# %%
pp = PrettyPrinter(indent=2)

# %%
fws_yaml = sorted(glob("fw_*.yaml"))

# %%
print(tabulate( [ [ row ] for row in fws_yaml ] ,headers=["Files"],tablefmt='simple'))
# Out:
# Files
# -------

# %%
print(wfb.show_attributes(exclude=["name"]))
# Out:
# --  ------------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -----------------------------------------  -----  ----  ------------------------------------------------  ----------  -------  ----------  -----
#     name                                              persistent                                                                                                                                                                                                                                                                                                                                                                                                                                   transient                                                                                                                                                                                                                                                                                                                                                                                                                                    template                                   order  dist  label                                             label_size  visited  degeneracy  fw_id
# 0   fw_010_file_retrieval.yaml_000010                 {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    fw_010_file_retrieval.yaml                 0      0     fw_010_file_retrieval.yaml_000010                 10          True     1           10
# 1   fw_020_minimization_fixed_box.yaml_000020         {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                              fw_020_minimization_fixed_box.yaml         1      1     fw_020_minimization_fixed_box.yaml_000020         10          True     1           20
# 2   fw_030_minimization_relaxed_box.yaml_000030       {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                              fw_030_minimization_relaxed_box.yaml       2      2     fw_030_minimization_relaxed_box.yaml_000030       10          True     1           30
# 3   fw_060_equilibration_nvt_bulk.yaml_000040         {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                              fw_060_equilibration_nvt_bulk.yaml         10     3     fw_060_equilibration_nvt_bulk.yaml_000040         10          True     1           40
# 4   fw_070_equilibration_npt_bulk.yaml_000050         {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '010_equilibration_npt_bulk_0_atm'}  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': 3600, 'queue': '', 'identifier': '010_equilibration_npt_bulk_0_atm'}         fw_070_equilibration_npt_bulk.yaml         11     4     fw_070_equilibration_npt_bulk.yaml_000050         10          True     2           50
# 5   fw_070_equilibration_npt_bulk.yaml_000060         {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '020_equilibration_npt_bulk_1_atm'}  {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': 3600, 'queue': '', 'identifier': '020_equilibration_npt_bulk_1_atm'}         fw_070_equilibration_npt_bulk.yaml         12     4     fw_070_equilibration_npt_bulk.yaml_000060         10          True     2           60
# 6   fw_100_extract_property.yaml_000070               {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '020_equilibration_npt_bulk_1_atm'}  {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '020_equilibration_npt_bulk_1_atm'}  fw_100_extract_property.yaml               14     5     fw_100_extract_property.yaml_000070               10          True     2           70
# 7   fw_150_remote_file_transfer.yaml_000080           {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '020_equilibration_npt_bulk_1_atm'}  {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '020_equilibration_npt_bulk_1_atm'}  fw_150_remote_file_transfer.yaml           15     6     fw_150_remote_file_transfer.yaml_000080           10          True     2           80
# 8   fw_100_extract_property.yaml_000090               {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '010_equilibration_npt_bulk_0_atm'}  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '010_equilibration_npt_bulk_0_atm'}  fw_100_extract_property.yaml               16     5     fw_100_extract_property.yaml_000090               10          True     2           90
# 9   fw_150_remote_file_transfer.yaml_000100           {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '010_equilibration_npt_bulk_0_atm'}  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '010_equilibration_npt_bulk_0_atm'}  fw_150_remote_file_transfer.yaml           13     6     fw_150_remote_file_transfer.yaml_000100           10          True     2           100
# 10  fw_040_minimization_slab_fixed_box.yaml_000110    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                              fw_040_minimization_slab_fixed_box.yaml    17     3     fw_040_minimization_slab_fixed_box.yaml_000110    10          True     1           110
# 11  fw_050_minimization_slab_relaxed_box.yaml_000120  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                              fw_050_minimization_slab_relaxed_box.yaml  18     4     fw_050_minimization_slab_relaxed_box.yaml_000120  10          True     1           120
# 12  fw_080_equilibration_nvt_slab.yaml_000130         {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                                    {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express'}                                              fw_080_equilibration_nvt_slab.yaml         3      5     fw_080_equilibration_nvt_slab.yaml_000130         10          True     1           130
# 13  fw_090_equilibration_npt_slab.yaml_000140         {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '030_equilibration_npt_slab_0_atm'}  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': 3600, 'queue': '', 'identifier': '030_equilibration_npt_slab_0_atm'}         fw_090_equilibration_npt_slab.yaml         5      6     fw_090_equilibration_npt_slab.yaml_000140         10          True     2           140
# 14  fw_090_equilibration_npt_slab.yaml_000150         {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '040_equilibration_npt_slab_1_atm'}  {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_queue_offline', 'nodes': 1, 'ppn': 20, 'walltime': 3600, 'queue': '', 'identifier': '040_equilibration_npt_slab_1_atm'}         fw_090_equilibration_npt_slab.yaml         6      6     fw_090_equilibration_npt_slab.yaml_000150         10          True     2           150
# 15  fw_100_extract_property.yaml_000160               {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '040_equilibration_npt_slab_1_atm'}  {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '040_equilibration_npt_slab_1_atm'}  fw_100_extract_property.yaml               7      7     fw_100_extract_property.yaml_000160               10          True     2           160
# 16  fw_150_remote_file_transfer.yaml_000170           {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '040_equilibration_npt_slab_1_atm'}  {'machine': 'NEMO', 'pressure': 1, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '040_equilibration_npt_slab_1_atm'}  fw_150_remote_file_transfer.yaml           4      8     fw_150_remote_file_transfer.yaml_000170           10          True     2           170
# 17  fw_100_extract_property.yaml_000180               {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '030_equilibration_npt_slab_0_atm'}  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '030_equilibration_npt_slab_0_atm'}  fw_100_extract_property.yaml               8      7     fw_100_extract_property.yaml_000180               10          True     2           180
# 18  fw_150_remote_file_transfer.yaml_000190           {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '030_equilibration_npt_slab_0_atm'}  {'machine': 'NEMO', 'pressure': 0, 'remote_user': 'testuser', 'remote_dir': '/mnt/dat/work/testuser/substrate/eam/series8', 'ssh_key': '/home/fr/fr_fr/fr_jh1130/.ssh/testuser-bwCloud', 'substrate_identifier': 'substrate/AU/111/52x30x8.lammps', 'surfactant': 'SDS', 'temperature': 298, 'worker': 'nemo_noqueue', 'nodes': 1, 'ppn': 20, 'walltime': '00:15:00', 'queue': 'express', 'identifier': '030_equilibration_npt_slab_0_atm'}  fw_150_remote_file_transfer.yaml           9      8     fw_150_remote_file_transfer.yaml_000190           10          True     2           190
# --  ------------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -----------------------------------------  -----  ----  ------------------------------------------------  ----------  -------  ----------  -----

# %%
pp.pprint(metadata)
# Out:
# { 'metadata': { 'pbc': 111,
#                 'pressure': 0,
#                 'pressure_unit': 'atm',
#                 'sb_area': 2.20374e-16,
#                 'sb_area_unit': 'm^2',
#                 'sb_crystal_plane': 111,
#                 'sb_measures': [1.47e-08, 1.5e-08, 5.6e-09],
#                 'sb_measures_unit': 'm',
#                 'sb_multiples': [51, 30, 8],
#                 'sb_name': 'AU_111_51x30x8',
#                 'sb_normal': 2,
#                 'sb_thickness': 5.6e-09,
#                 'sb_thickness_unit': 'm',
#                 'sb_unit_cell': ['3e-10', '5e-10', '7e-10'],
#                 'sb_unit_cell_unit': 'm',
#                 'sb_volume': 3.11331e-25,
#                 'sb_volume_unit': 'm^3',
#                 'state': 'trial minimization with eam potential',
#                 'substrate': 'AU',
#                 'system_name': 'AU_111_51x30x8',
#                 'temperature': 298,
#                 'temperature_unit': 'K'},
#   'name': 'NEMO TRIAL: LAMMPS minimization and equilibration of EAM substrate'}

# %%
assert "metadata" in metadata

# %%
assert "name" in metadata

# %%
fws_id = { fw: (-10*(i+1)) for i, fw in enumerate(fws_set) }

# %%
pp.pprint(fws_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1948-a08296110e02> in <module>()
# ----> 1 pp.pprint(fws_id)
#
# NameError: name 'fws_id' is not defined

# %%
fws_dict = { fw: Firework.from_file(fw, f_format='yaml') for fw in fws_set }

# %%
for name, fw in fws_dict.items():
    fw.fw_id = fws_id[name]

# %%
links = { 
    fws_dict[parent]: [ 
        fws_dict[child] for child in children ] for parent, children in dependencies.items() }

# %%
fws_list = list(fws_dict.values())

# %%
wf = Workflow( fws_list, links, name=metadata["name"], metadata=metadata["metadata"]  )

# %%
wf.to_file("wf.yaml",f_format='yaml')
